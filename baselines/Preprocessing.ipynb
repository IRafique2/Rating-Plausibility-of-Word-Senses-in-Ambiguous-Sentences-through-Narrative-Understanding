# %% [markdown]
# # Import statments

# %%
import json

# %% [markdown]
# # Import data

# %%
data_path = '/content/data/'
with open(f'{data_path}train.json', 'r') as f:
    train_data = json.load(f)

with open(f'{data_path}dev.json', 'r') as f:
    dev_data = json.load(f)

# %% [markdown]
# # Dataset Inspection

# %%
numeric_homonyms = []

for entry_id, entry_data in train_data.items():
    homonym = entry_data.get('homonym')
    if isinstance(homonym, (int, float)): # Check for actual numeric types
        numeric_homonyms.append(homonym)
    elif isinstance(homonym, str) and homonym.isnumeric(): # Check if string can be numeric
        numeric_homonyms.append(homonym)

for entry_id, entry_data in dev_data.items():
    homonym = entry_data.get('homonym')
    if isinstance(homonym, (int, float)): # Check for actual numeric types
        numeric_homonyms.append(homonym)
    elif isinstance(homonym, str) and homonym.isnumeric(): # Check if string can be numeric
        numeric_homonyms.append(homonym)

if numeric_homonyms:
    print(f"Found numeric entries in 'homonym' column: {list(set(numeric_homonyms))}")
else:
    print("No numeric entries found in 'homonym' column.")
# Out:
# No numeric entries found in 'homonym' column.

# %%
# Collect 'choices' lists and convert to tuples for uniqueness check
all_choicess = []
for entry_id, entry_data in train_data.items():
    if 'choices' in entry_data and isinstance(entry_data['choices'], list):
        all_choicess.append(tuple(entry_data['choices']))
for entry_id, entry_data in dev_data.items():
    if 'choices' in entry_data and isinstance(entry_data['choices'], list):
        all_choicess.append(tuple(entry_data['choices']))
unique_choicess = set(all_choicess)
print(f"Number of unique 'choices' combinations: {len(unique_choicess)}")
print(f"Example unique 'choices' combinations (first 5): {list(unique_choicess)[:5]}\n")

# Collect 'nonsensical' lists and convert to tuples for uniqueness check
all_nonsensical = []
for entry_id, entry_data in train_data.items():
    if 'nonsensical' in entry_data and isinstance(entry_data['nonsensical'], list):
        all_nonsensical.append(tuple(entry_data['nonsensical']))
for entry_id, entry_data in dev_data.items():
    if 'nonsensical' in entry_data and isinstance(entry_data['nonsensical'], list):
        all_nonsensical.append(tuple(entry_data['nonsensical']))
unique_nonsensical = set(all_nonsensical)
print(f"Number of unique 'nonsensical' combinations: {len(unique_nonsensical)}")
print(f"Example unique 'nonsensical' combinations (first 5): {list(unique_nonsensical)[:5]}")
# Out:
# Number of unique 'choices' combinations: 1351
# Example unique 'choices' combinations (first 5): [(2, 4, 4, 1, 2), (2, 3, 4, 4, 5), (2, 4, 4, 2, 3), (1, 2, 3, 1, 4), (4, 3, 4, 2, 2)]
#
# Number of unique 'nonsensical' combinations: 22
# Example unique 'nonsensical' combinations (first 5): [(False, True, False, False, True), (False, False, True, False, False), (True, False, False, False, False, False), (True, False, True, True, False), (False, False, False, False, False)]

# %%
numbers_outside_range = set()

# Check train_data
for entry_id, entry_data in train_data.items():
    if 'choices' in entry_data and isinstance(entry_data['choices'], list):
        for num in entry_data['choices']:
            if not (1 <= num <= 5):
                numbers_outside_range.add(num)

# Check dev_data
for entry_id, entry_data in dev_data.items():
    if 'choices' in entry_data and isinstance(entry_data['choices'], list):
        for num in entry_data['choices']:
            if not (1 <= num <= 5):
                numbers_outside_range.add(num)

if numbers_outside_range:
    print(f"Found numbers outside the 1-5 range in 'choices': {sorted(list(numbers_outside_range))}")
else:
    print("All numbers in 'choices' combinations are within the 1-5 range.")
# Out:
# All numbers in 'choices' combinations are within the 1-5 range.

# %%
columns_to_check_for_non_numeric = ['average', 'stdev']
non_numeric_entries_found = {col: [] for col in columns_to_check_for_non_numeric}

# Helper function to check if a value is numeric
def is_numeric(value):
    if isinstance(value, (int, float)):
        return True
    if isinstance(value, str):
        try:
            float(value) # Try converting to float
            return True
        except ValueError:
            return False
    return False

# Check train_data
for entry_id, entry_data in train_data.items():
    for col in columns_to_check_for_non_numeric:
        value = entry_data.get(col)
        if not is_numeric(value):
            non_numeric_entries_found[col].append(value)

# Check dev_data
for entry_id, entry_data in dev_data.items():
    for col in columns_to_check_for_non_numeric:
        value = entry_data.get(col)
        if not is_numeric(value):
            non_numeric_entries_found[col].append(value)

print("\nNon-numeric entries check results for 'average' and 'stdev':")
for col, entries in non_numeric_entries_found.items():
    if entries:
        # Display unique non-numeric entries
        print(f"  Found non-numeric entries in '{col}': {list(set(entries))}")
    else:
        print(f"  No non-numeric entries found in '{col}'.")
# Out:
# Non-numeric entries check results for 'average' and 'stdev':
#   No non-numeric entries found in 'average'.
#   No non-numeric entries found in 'stdev'.

# %%
columns_to_check = ['judged_meaning', 'precontext', 'sentence', 'ending']
numeric_entries_found = {col: [] for col in columns_to_check}

# Check train_data
for entry_id, entry_data in train_data.items():
    for col in columns_to_check:
        value = entry_data.get(col)
        if isinstance(value, (int, float)): # Check for actual numeric types
            numeric_entries_found[col].append(value)
        elif isinstance(value, str) and value.isnumeric(): # Check if string can be numeric
            numeric_entries_found[col].append(value)

# Check dev_data
for entry_id, entry_data in dev_data.items():
    for col in columns_to_check:
        value = entry_data.get(col)
        if isinstance(value, (int, float)): # Check for actual numeric types
            numeric_entries_found[col].append(value)
        elif isinstance(value, str) and value.isnumeric(): # Check if string can be numeric
            numeric_entries_found[col].append(value)

print("\nNumeric entries check results:")
for col, entries in numeric_entries_found.items():
    if entries:
        print(f"  Found numeric entries in '{col}': {list(set(entries))}")
    else:
        print(f"  No numeric entries found in '{col}'.")
# Out:
# Numeric entries check results:
#   No numeric entries found in 'judged_meaning'.
#   No numeric entries found in 'precontext'.
#   No numeric entries found in 'sentence'.
#   No numeric entries found in 'ending'.

# %%
# Convert dict-of-dicts → list of entries
samples = list(data.values())

# %%
def get_story_key(sample):
    return (
        sample["homonym"],
        sample["precontext"],
        sample["sentence"],
        sample.get("ending", None)
    )

# %%
story_groups = defaultdict(list)

for s in samples:
    key = get_story_key(s)
    story_groups[key].append(s)

# %%
for story_key, items in story_groups.items():
    num = len(items)
    print("\nStory key:", story_key)
    print("Number of sense-samples:", num)
    for it in items:
        print("   - judged_meaning:", it["judged_meaning"])
# Out:
# Story key: ('potential', 'The old machine hummed in the corner of the workshop. Clara examined its dusty dials with a furrowed brow. She wondered if it could be brought back to life.', "The potential couldn't be measured.", 'She collected a battery reader and looked on earnestly, willing some life back into the old machine.')
# Number of sense-samples: 2
#    - judged_meaning: the difference in electrical charge between two points in a circuit expressed in volts
#    - judged_meaning: the inherent capacity for coming into being
#
# Story key: ('potential', 'The old machine hummed in the corner of the workshop. Clara examined its dusty dials with a furrowed brow. She wondered if it could be brought back to life.', "The potential couldn't be measured.", 'The machine could make such wonderful clothing if it were in working order.')
# Number of sense-samples: 2
#    - judged_meaning: the difference in electrical charge between two points in a circuit expressed in volts
#    - judged_meaning: the inherent capacity for coming into being
#
# Story key: ('potential', 'The old machine hummed in the corner of the workshop. Clara examined its dusty dials with a furrowed brow. She wondered if it could be brought back to life.', "The potential couldn't be measured.", '')
# Number of sense-samples: 2
#    - judged_meaning: the difference in electrical charge between two points in a circuit expressed in volts
#    - judged_meaning: the inherent capacity for coming into being
#
# Story key: ('base', 'The troops were stationed at a remote camp for training. To pass the time, they often engaged in recreational sports. One afternoon, they decided to play a game on the field next to their tents.', 'The soldiers were playing a bat and ball game, which involved them running towards the base.', 'Unfortunately, the sentries saw them approaching and shot them all dead.')
# Number of sense-samples: 2
#    - judged_meaning: installation from which a military force initiates operations
#    - judged_meaning: a place that the runner must touch before scoring
#
# Story key: ('base', 'The troops were stationed at a remote camp for training. To pass the time, they often engaged in recreational sports. One afternoon, they decided to play a game on the field next to their tents.', 'The soldiers were playing a bat and ball game, which involved them running towards the base.', "It didn't take long for the winning team to get a home run.")
# Number of sense-samples: 2
#    - judged_meaning: installation from which a military force initiates operations
#    - judged_meaning: a place that the runner must touch before scoring
#
# Story key: ('base', 'The troops were stationed at a remote camp for training. To pass the time, they often engaged in recreational sports. One afternoon, they decided to play a game on the field next to their tents.', 'The soldiers were playing a bat and ball game, which involved them running towards the base.', '')
# Number of sense-samples: 2
#    - judged_meaning: installation from which a military force initiates operations
#    - judged_meaning: a place that the runner must touch before scoring
#
# Story key: ('driving', 'Poppy had a unique impact on her friends. They often found themselves doing things they never planned to do. Her enthusiasm was hard to resist, no matter how hesitant they felt.', "Poppy was always driving her friends, although they wished she wouldn't.", 'Just for once, she wished that her friends would plan a get-together or adventure, and she could enjoy being present.')
# Number of sense-samples: 2
#    - judged_meaning: to compel or force or urge relentlessly or exert coercive pressure on, or motivate strongly
#    - judged_meaning: operate or control a vehicle
#
# Story key: ('driving', 'Poppy had a unique impact on her friends. They often found themselves doing things they never planned to do. Her enthusiasm was hard to resist, no matter how hesitant they felt.', "Poppy was always driving her friends, although they wished she wouldn't.", 'Poppy would be the one to take them from their houses to events and restaurants.')
# Number of sense-samples: 2
#    - judged_meaning: to compel or force or urge relentlessly or exert coercive pressure on, or motivate strongly
#    - judged_meaning: operate or control a vehicle
#
# Story key: ('driving', 'Poppy had a unique impact on her friends. They often found themselves doing things they never planned to do. Her enthusiasm was hard to resist, no matter how hesitant they felt.', "Poppy was always driving her friends, although they wished she wouldn't.", '')
# Number of sense-samples: 2
#    - judged_meaning: to compel or force or urge relentlessly or exert coercive pressure on, or motivate strongly
#    - judged_meaning: operate or control a vehicle
#
# Story key: ('drive', 'John glanced at his watch and sighed. It had been a busy afternoon filled with back-to-back meetings. The evening sky was beginning to darken as he packed up his bag.', 'He was ready to drive after a long day.', "He started the car, and the engine roared to life. He sped off down the country lanes into the sunset; he'd been waiting for this moment all day.")
# Number of sense-samples: 2
#    - judged_meaning: a journey in a vehicle (usually an automobile)
#    - judged_meaning: hitting a golf ball off of a tee with a driver
#
# Story key: ('drive', 'John glanced at his watch and sighed. It had been a busy afternoon filled with back-to-back meetings. The evening sky was beginning to darken as he packed up his bag.', 'He was ready to drive after a long day.', "As he settled into his car, he couldn't help but think about the satisfying feeling of sending the ball soaring down the fairway during his weekend games.")
# Number of sense-samples: 2
#    - judged_meaning: a journey in a vehicle (usually an automobile)
#    - judged_meaning: hitting a golf ball off of a tee with a driver
#
# Story key: ('drive', 'John glanced at his watch and sighed. It had been a busy afternoon filled with back-to-back meetings. The evening sky was beginning to darken as he packed up his bag.', 'He was ready to drive after a long day.', '')
# Number of sense-samples: 2
#    - judged_meaning: a journey in a vehicle (usually an automobile)
#    - judged_meaning: hitting a golf ball off of a tee with a driver
#
# Story key: ('drive', "Tom woke up early that morning. He had been looking forward to today for weeks. As he got ready, he couldn't stop thinking about what lay ahead.", 'That was a good drive.', 'He put on his driving gloves and was ready.')
# Number of sense-samples: 2
#    - judged_meaning: a journey in a vehicle (usually an automobile)
#    - judged_meaning: hitting a golf ball off of a tee with a driver
#
# Story key: ('drive', "Tom woke up early that morning. He had been looking forward to today for weeks. As he got ready, he couldn't stop thinking about what lay ahead.", 'That was a good drive.', 'Tom was proud of how his golf game was going.')
# Number of sense-samples: 2
#    - judged_meaning: a journey in a vehicle (usually an automobile)
#    - judged_meaning: hitting a golf ball off of a tee with a driver
#
# Story key: ('drive', "Tom woke up early that morning. He had been looking forward to today for weeks. As he got ready, he couldn't stop thinking about what lay ahead.", 'That was a good drive.', '')
# Number of sense-samples: 2
#    - judged_meaning: a journey in a vehicle (usually an automobile)
#    - judged_meaning: hitting a golf ball off of a tee with a driver
#
# Story key: ('drive', 'Jack packed his bags and left the house early. The weather was perfect for the day ahead. He was eager to test his skills and patience.', 'The drive was a good distance.', 'After hours on the road, Jack finally arrived at his destination, ready to face the challenges of the day.')
# Number of sense-samples: 2
#    - judged_meaning: a journey in a vehicle (usually an automobile)
#    - judged_meaning: hitting a golf ball off of a tee with a driver
#
# Story key: ('drive', 'Jack packed his bags and left the house early. The weather was perfect for the day ahead. He was eager to test his skills and patience.', 'The drive was a good distance.', 'He was excited to see how far he could hit the ball.')
# Number of sense-samples: 2
#    - judged_meaning: a journey in a vehicle (usually an automobile)
#    - judged_meaning: hitting a golf ball off of a tee with a driver
#
# Story key: ('drive', 'Jack packed his bags and left the house early. The weather was perfect for the day ahead. He was eager to test his skills and patience.', 'The drive was a good distance.', '')
# Number of sense-samples: 2
#    - judged_meaning: a journey in a vehicle (usually an automobile)
#    - judged_meaning: hitting a golf ball off of a tee with a driver
#
# Story key: ('drive', 'Lisa had always been competitive. Every weekend, she dedicated herself to her passion. She believed that her relentless practice would pay off someday.', 'Her drive was what ultimately got her into the top university.', 'She made that long trip to show the course coordinators her dedication to going to that university, and they said that was one of the reasons why they accepted her.')
# Number of sense-samples: 2
#    - judged_meaning: a journey in a vehicle (usually an automobile)
#    - judged_meaning: hitting a golf ball off of a tee with a driver
#
# Story key: ('drive', 'Lisa had always been competitive. Every weekend, she dedicated herself to her passion. She believed that her relentless practice would pay off someday.', 'Her drive was what ultimately got her into the top university.', 'She felt immensely proud of herself.')
# Number of sense-samples: 2
#    - judged_meaning: a journey in a vehicle (usually an automobile)
#    - judged_meaning: hitting a golf ball off of a tee with a driver
#
# Story key: ('drive', 'Lisa had always been competitive. Every weekend, she dedicated herself to her passion. She believed that her relentless practice would pay off someday.', 'Her drive was what ultimately got her into the top university.', '')
# Number of sense-samples: 2
#    - judged_meaning: a journey in a vehicle (usually an automobile)
#    - judged_meaning: hitting a golf ball off of a tee with a driver
#
# Story key: ('front', 'It was a gray morning, and everyone in town braced themselves for the coming change. The sky darkened as the day went on, casting an eerie shadow over the old buildings. People gathered at the edge of the street, whispering about what was approaching.', 'The front was something to behold.', 'It heralded a huge storm.')
# Number of sense-samples: 2
#    - judged_meaning: (meteorology) the atmospheric phenomenon created at the boundary between two different air masses
#    - judged_meaning: the side that is forward or prominent
#
# Story key: ('front', 'It was a gray morning, and everyone in town braced themselves for the coming change. The sky darkened as the day went on, casting an eerie shadow over the old buildings. People gathered at the edge of the street, whispering about what was approaching.', 'The front was something to behold.', 'The buildings seemed almost decrepit as the weather change loomed.')
# Number of sense-samples: 2
#    - judged_meaning: (meteorology) the atmospheric phenomenon created at the boundary between two different air masses
#    - judged_meaning: the side that is forward or prominent
#
# Story key: ('front', 'It was a gray morning, and everyone in town braced themselves for the coming change. The sky darkened as the day went on, casting an eerie shadow over the old buildings. People gathered at the edge of the street, whispering about what was approaching.', 'The front was something to behold.', '')
# Number of sense-samples: 2
#    - judged_meaning: (meteorology) the atmospheric phenomenon created at the boundary between two different air masses
#    - judged_meaning: the side that is forward or prominent
#
# Story key: ('appendix', 'John had always been curious about things that stood out. Whether it was a rare book at the library or a peculiar x-ray from his anatomy class, he would spend hours examining them. One day, he stumbled upon something unusual that caught his attention.', 'The appendix was so different, one could notice it instantly.', 'The author had written them in bold font as if he wanted people to notice them.')
# Number of sense-samples: 2
#    - judged_meaning: supplementary material that is collected and appended at the back of a book
#    - judged_meaning: a vestigial process that extends from the lower end of the cecum and that resembles a small pouch
#
# Story key: ('appendix', 'John had always been curious about things that stood out. Whether it was a rare book at the library or a peculiar x-ray from his anatomy class, he would spend hours examining them. One day, he stumbled upon something unusual that caught his attention.', 'The appendix was so different, one could notice it instantly.', 'He was so captivated by the uniqueness that he decided to carry out research before treatment.')
# Number of sense-samples: 2
#    - judged_meaning: supplementary material that is collected and appended at the back of a book
#    - judged_meaning: a vestigial process that extends from the lower end of the cecum and that resembles a small pouch
#
# Story key: ('appendix', 'John had always been curious about things that stood out. Whether it was a rare book at the library or a peculiar x-ray from his anatomy class, he would spend hours examining them. One day, he stumbled upon something unusual that caught his attention.', 'The appendix was so different, one could notice it instantly.', '')
# Number of sense-samples: 2
#    - judged_meaning: supplementary material that is collected and appended at the back of a book
#    - judged_meaning: a vestigial process that extends from the lower end of the cecum and that resembles a small pouch
#
# Story key: ('appendix', 'John had been working on his novel for months, pouring over every chapter. He was determined to have it completed by the end of the week. However, there had been an unexpected delay in his progress.', 'John was late completing the book because he had been having trouble with his appendix.', "He wasn't sure if he should reference all the other research articles that had been used in putting his novel together with such accuracy.")
# Number of sense-samples: 2
#    - judged_meaning: supplementary material that is collected and appended at the back of a book
#    - judged_meaning: a vestigial process that extends from the lower end of the cecum and that resembles a small pouch
#
# Story key: ('appendix', 'John had been working on his novel for months, pouring over every chapter. He was determined to have it completed by the end of the week. However, there had been an unexpected delay in his progress.', 'John was late completing the book because he had been having trouble with his appendix.', 'It had been causing him a lot of pain in his lower abdomen recently.')
# Number of sense-samples: 2
#    - judged_meaning: supplementary material that is collected and appended at the back of a book
#    - judged_meaning: a vestigial process that extends from the lower end of the cecum and that resembles a small pouch
#
# Story key: ('appendix', 'John had been working on his novel for months, pouring over every chapter. He was determined to have it completed by the end of the week. However, there had been an unexpected delay in his progress.', 'John was late completing the book because he had been having trouble with his appendix.', '')
# Number of sense-samples: 2
#    - judged_meaning: supplementary material that is collected and appended at the back of a book
#    - judged_meaning: a vestigial process that extends from the lower end of the cecum and that resembles a small pouch
#
# Story key: ('appendicitis', 'The writer sat at his cluttered desk, surrounded by piles of paper and empty coffee cups. He had been working tirelessly on his latest book, determined to finish it by the looming deadline. However, a dull ache had started to distract him from his work.', 'The writer was struggling with his appendicitis.', 'The only option was to gather the papers in order so he could make a list.')
# Number of sense-samples: 2
#    - judged_meaning: supplementary material that is collected and appended at the back of a book
#    - judged_meaning: a vestigial process that extends from the lower end of the cecum and that resembles a small pouch
#
# Story key: ('appendicitis', 'The writer sat at his cluttered desk, surrounded by piles of paper and empty coffee cups. He had been working tirelessly on his latest book, determined to finish it by the looming deadline. However, a dull ache had started to distract him from his work.', 'The writer was struggling with his appendicitis.', 'He would need to go to the hospital to have the organ removed.')
# Number of sense-samples: 2
#    - judged_meaning: supplementary material that is collected and appended at the back of a book
#    - judged_meaning: a vestigial process that extends from the lower end of the cecum and that resembles a small pouch
#
# Story key: ('appendicitis', 'The writer sat at his cluttered desk, surrounded by piles of paper and empty coffee cups. He had been working tirelessly on his latest book, determined to finish it by the looming deadline. However, a dull ache had started to distract him from his work.', 'The writer was struggling with his appendicitis.', '')
# Number of sense-samples: 2
#    - judged_meaning: supplementary material that is collected and appended at the back of a book
#    - judged_meaning: a vestigial process that extends from the lower end of the cecum and that resembles a small pouch
#
# Story key: ('temple', 'The night was calm and quiet. They walked through the old city streets. The air was filled with a sense of mystery.', 'Their temple glowed in the moonlight.', 'Then, they all bowed down in silence.')
# Number of sense-samples: 2
#    - judged_meaning: (Judaism) the place of worship for a Jewish congregation
#    - judged_meaning: the flat area on either side of the forehead
#
# Story key: ('temple', 'The night was calm and quiet. They walked through the old city streets. The air was filled with a sense of mystery.', 'Their temple glowed in the moonlight.', 'They had to mop the sweat away.')
# Number of sense-samples: 2
#    - judged_meaning: (Judaism) the place of worship for a Jewish congregation
#    - judged_meaning: the flat area on either side of the forehead
#
# Story key: ('temple', 'The night was calm and quiet. They walked through the old city streets. The air was filled with a sense of mystery.', 'Their temple glowed in the moonlight.', '')
# Number of sense-samples: 2
#    - judged_meaning: (Judaism) the place of worship for a Jewish congregation
#    - judged_meaning: the flat area on either side of the forehead
#
# Story key: ('catch', 'John had found an unusual box at the back of the attic. Inside, there were strange trinkets and a dusty old map. He was excited but also a little wary of what he had discovered.', "He couldn't figure out the catch.", 'One thing was clear: his next adventure lay in the mystery of the map.')
# Number of sense-samples: 2
#    - judged_meaning: a drawback or difficulty that is not readily evident
#    - judged_meaning: the quantity that was caught
#
# Story key: ('catch', 'John had found an unusual box at the back of the attic. Inside, there were strange trinkets and a dusty old map. He was excited but also a little wary of what he had discovered.', "He couldn't figure out the catch.", 'He set it aside and called his friend for advice.')
# Number of sense-samples: 2
#    - judged_meaning: a drawback or difficulty that is not readily evident
#    - judged_meaning: the quantity that was caught
#
# Story key: ('catch', 'John had found an unusual box at the back of the attic. Inside, there were strange trinkets and a dusty old map. He was excited but also a little wary of what he had discovered.', "He couldn't figure out the catch.", '')
# Number of sense-samples: 2
#    - judged_meaning: a drawback or difficulty that is not readily evident
#    - judged_meaning: the quantity that was caught
#
# Story key: ('cleanly', 'Jason had prepared for months for the local robotics competition. His robot, EcoBot, was designed to perform complex obstacle courses. The goal was to maneuver smoothly and efficiently through the course while showcasing innovative technology.', 'He exited the competition cleanly, impressing both the judges and the organizers.', "It couldn't have gone any better.")
# Number of sense-samples: 2
#    - judged_meaning: in an adroit manner
#    - judged_meaning: in a manner that minimizes dirt and pollution
#
# Story key: ('cleanly', 'Jason had prepared for months for the local robotics competition. His robot, EcoBot, was designed to perform complex obstacle courses. The goal was to maneuver smoothly and efficiently through the course while showcasing innovative technology.', 'He exited the competition cleanly, impressing both the judges and the organizers.', 'He left no trace of ever being on the course and won first place as a result.')
# Number of sense-samples: 2
#    - judged_meaning: in an adroit manner
#    - judged_meaning: in a manner that minimizes dirt and pollution
#
# Story key: ('cleanly', 'Jason had prepared for months for the local robotics competition. His robot, EcoBot, was designed to perform complex obstacle courses. The goal was to maneuver smoothly and efficiently through the course while showcasing innovative technology.', 'He exited the competition cleanly, impressing both the judges and the organizers.', '')
# Number of sense-samples: 2
#    - judged_meaning: in an adroit manner
#    - judged_meaning: in a manner that minimizes dirt and pollution
#
# Story key: ('cleanly', 'Linda had always been meticulous with her work. Today, she faced her biggest challenge yet: a delicate fabric that required precision. The scissors in her hand felt like an extension of herself. ', 'She sliced through the fabric cleanly, leaving no mess behind.', 'With such precision, there was not any waste of material.')
# Number of sense-samples: 2
#    - judged_meaning: in an adroit manner
#    - judged_meaning: in a manner that minimizes dirt and pollution
#
# Story key: ('cleanly', 'Linda had always been meticulous with her work. Today, she faced her biggest challenge yet: a delicate fabric that required precision. The scissors in her hand felt like an extension of herself. ', 'She sliced through the fabric cleanly, leaving no mess behind.', 'She was relieved, as any sullying of the material would have meant starting again from scratch, which would have been an expensive mistake to make.')
# Number of sense-samples: 2
#    - judged_meaning: in an adroit manner
#    - judged_meaning: in a manner that minimizes dirt and pollution
#
# Story key: ('cleanly', 'Linda had always been meticulous with her work. Today, she faced her biggest challenge yet: a delicate fabric that required precision. The scissors in her hand felt like an extension of herself. ', 'She sliced through the fabric cleanly, leaving no mess behind.', '')
# Number of sense-samples: 2
#    - judged_meaning: in an adroit manner
#    - judged_meaning: in a manner that minimizes dirt and pollution
#
# Story key: ('cleanly', 'The group arrived at the park just before noon with a few picnic baskets. They spread out a large blanket on the grass and set up a small table. Everyone was excited to enjoy the day and have a meal together.', 'They tried to share and serve the food as cleanly as possible.', 'Everyone was given the exact same portions.')
# Number of sense-samples: 2
#    - judged_meaning: in an adroit manner
#    - judged_meaning: in a manner that minimizes dirt and pollution
#
# Story key: ('cleanly', 'The group arrived at the park just before noon with a few picnic baskets. They spread out a large blanket on the grass and set up a small table. Everyone was excited to enjoy the day and have a meal together.', 'They tried to share and serve the food as cleanly as possible.', 'Having paper plates definitely helped everyone at the end of the picnic.')
# Number of sense-samples: 2
#    - judged_meaning: in an adroit manner
#    - judged_meaning: in a manner that minimizes dirt and pollution
#
# Story key: ('cleanly', 'The group arrived at the park just before noon with a few picnic baskets. They spread out a large blanket on the grass and set up a small table. Everyone was excited to enjoy the day and have a meal together.', 'They tried to share and serve the food as cleanly as possible.', '')
# Number of sense-samples: 2
#    - judged_meaning: in an adroit manner
#    - judged_meaning: in a manner that minimizes dirt and pollution
#
# Story key: ('withdrawal', 'John had always been meticulous with his habits. Every morning, he visited the bank or the pharmacy on his way to work. That day, he decided to make a change in his routine.', 'After the sudden withdrawal, he felt anxious and unsteady all day.', 'It felt unsafe to have taken so much money from his account in one go.')
# Number of sense-samples: 2
#    - judged_meaning: the act of taking out money or other capital
#    - judged_meaning: the termination of drug taking
#
# Story key: ('withdrawal', 'John had always been meticulous with his habits. Every morning, he visited the bank or the pharmacy on his way to work. That day, he decided to make a change in his routine.', 'After the sudden withdrawal, he felt anxious and unsteady all day.', 'This was day one of trying to get clean.')
# Number of sense-samples: 2
#    - judged_meaning: the act of taking out money or other capital
#    - judged_meaning: the termination of drug taking
#
# Story key: ('withdrawal', 'John had always been meticulous with his habits. Every morning, he visited the bank or the pharmacy on his way to work. That day, he decided to make a change in his routine.', 'After the sudden withdrawal, he felt anxious and unsteady all day.', '')
# Number of sense-samples: 2
#    - judged_meaning: the act of taking out money or other capital
#    - judged_meaning: the termination of drug taking
#
# Story key: ('withdrawal', 'John sat quietly at the table, staring at the letter in his hands. He remembered the advice his friend had given him, but his mind was still unsettled. The decision had weighed heavily on him for days.', 'The withdrawal was really difficult.', 'He sighed as he walked to the bank, knowing that taking out the money for the investment was a necessary but tough decision.')
# Number of sense-samples: 2
#    - judged_meaning: the act of taking out money or other capital
#    - judged_meaning: the termination of drug taking
#
# Story key: ('withdrawal', 'John sat quietly at the table, staring at the letter in his hands. He remembered the advice his friend had given him, but his mind was still unsettled. The decision had weighed heavily on him for days.', 'The withdrawal was really difficult.', "He couldn't get over the way he was feeling.")
# Number of sense-samples: 2
#    - judged_meaning: the act of taking out money or other capital
#    - judged_meaning: the termination of drug taking
#
# Story key: ('withdrawal', 'John sat quietly at the table, staring at the letter in his hands. He remembered the advice his friend had given him, but his mind was still unsettled. The decision had weighed heavily on him for days.', 'The withdrawal was really difficult.', '')
# Number of sense-samples: 2
#    - judged_meaning: the act of taking out money or other capital
#    - judged_meaning: the termination of drug taking
#
# Story key: ('joke', 'Mary received an unexpected invitation on Wednesday. It was a fancy letter, sealed with a golden sticker and decorated with colorful confetti. Her friends told her it was probably just a prank.', 'She thought that this was one big joke.', "She really couldn't stop laughing.")
# Number of sense-samples: 2
#    - judged_meaning: a humorous anecdote or remark intended to provoke laughter
#    - judged_meaning: a triviality not to be taken seriously
#
# Story key: ('joke', 'Mary received an unexpected invitation on Wednesday. It was a fancy letter, sealed with a golden sticker and decorated with colorful confetti. Her friends told her it was probably just a prank.', 'She thought that this was one big joke.', "She didn't even bother opening it as she, disinterestedly, stuck it in a pile of junk mail and leaflets.")
# Number of sense-samples: 2
#    - judged_meaning: a humorous anecdote or remark intended to provoke laughter
#    - judged_meaning: a triviality not to be taken seriously
#
# Story key: ('joke', 'Mary received an unexpected invitation on Wednesday. It was a fancy letter, sealed with a golden sticker and decorated with colorful confetti. Her friends told her it was probably just a prank.', 'She thought that this was one big joke.', '')
# Number of sense-samples: 2
#    - judged_meaning: a humorous anecdote or remark intended to provoke laughter
#    - judged_meaning: a triviality not to be taken seriously
#
# Story key: ('landing', 'Tom gripped the worn railing as he ascended the staircase, heart pounding with every step. He could hear the whirr of engines echoing faintly in the background. Each creak underfoot brought a growing sense of anticipation.', 'The landing was rough.', 'When he reached the top of the stairs, the crowd cheered.')
# Number of sense-samples: 2
#    - judged_meaning: an intermediate platform in a staircase
#    - judged_meaning: the act of coming down to the earth (or other surface)
#
# Story key: ('landing', 'Tom gripped the worn railing as he ascended the staircase, heart pounding with every step. He could hear the whirr of engines echoing faintly in the background. Each creak underfoot brought a growing sense of anticipation.', 'The landing was rough.', 'The engine slowed to a halt, and he steadied himself against the wall. Soon, he realized that they were no longer in motion.')
# Number of sense-samples: 2
#    - judged_meaning: an intermediate platform in a staircase
#    - judged_meaning: the act of coming down to the earth (or other surface)
#
# Story key: ('landing', 'Tom gripped the worn railing as he ascended the staircase, heart pounding with every step. He could hear the whirr of engines echoing faintly in the background. Each creak underfoot brought a growing sense of anticipation.', 'The landing was rough.', '')
# Number of sense-samples: 2
#    - judged_meaning: an intermediate platform in a staircase
#    - judged_meaning: the act of coming down to the earth (or other surface)
#
# Story key: ('faults', "The explorer gazed out at the vast landscape stretching before him. He marveled at the planet's incredible beauty yet sensed something foreboding. As he ventured further, he couldn't shake the feeling that something was amiss.", 'The Earth has many faults.', "But despite that, we can still appreciate nature's perfect imperfections.")
# Number of sense-samples: 2
#    - judged_meaning: the quality of being inadequate or falling short of perfection
#    - judged_meaning: (geology) a crack in the earth's crust resulting from the displacement of one side with respect to the other
#
# Story key: ('faults', "The explorer gazed out at the vast landscape stretching before him. He marveled at the planet's incredible beauty yet sensed something foreboding. As he ventured further, he couldn't shake the feeling that something was amiss.", 'The Earth has many faults.', 'The landscape lacks the ability to sustain life forms for long.')
# Number of sense-samples: 2
#    - judged_meaning: the quality of being inadequate or falling short of perfection
#    - judged_meaning: (geology) a crack in the earth's crust resulting from the displacement of one side with respect to the other
#
# Story key: ('faults', "The explorer gazed out at the vast landscape stretching before him. He marveled at the planet's incredible beauty yet sensed something foreboding. As he ventured further, he couldn't shake the feeling that something was amiss.", 'The Earth has many faults.', '')
# Number of sense-samples: 2
#    - judged_meaning: the quality of being inadequate or falling short of perfection
#    - judged_meaning: (geology) a crack in the earth's crust resulting from the displacement of one side with respect to the other
#
# Story key: ('degree', 'John always dreamed of being the best scientist. He spent years studying and experimenting tirelessly. His professor noticed his dedication and encouraged him to aim higher.', 'He has to work extremely hard to reach the highest degree in his field.', 'As a result of this, he found a job at an accredited scientific business.')
# Number of sense-samples: 2
#    - judged_meaning: an award conferred by a college or university signifying that the recipient has satisfactorily completed a course of study
#    - judged_meaning: a position on a scale of intensity or amount or quality
#
# Story key: ('degree', 'John always dreamed of being the best scientist. He spent years studying and experimenting tirelessly. His professor noticed his dedication and encouraged him to aim higher.', 'He has to work extremely hard to reach the highest degree in his field.', 'John continued to work hard after finishing his education.')
# Number of sense-samples: 2
#    - judged_meaning: an award conferred by a college or university signifying that the recipient has satisfactorily completed a course of study
#    - judged_meaning: a position on a scale of intensity or amount or quality
#
# Story key: ('degree', 'John always dreamed of being the best scientist. He spent years studying and experimenting tirelessly. His professor noticed his dedication and encouraged him to aim higher.', 'He has to work extremely hard to reach the highest degree in his field.', '')
# Number of sense-samples: 2
#    - judged_meaning: an award conferred by a college or university signifying that the recipient has satisfactorily completed a course of study
#    - judged_meaning: a position on a scale of intensity or amount or quality
#
# Story key: ('tick', 'Tom settled into his new cabin deep in the woods, excited for some peace and quiet. The old floorboards creaked whenever he walked over them. During the night, an odd noise kept echoing through the silent room.', 'He was up all night because of the tick.', 'He decided the following day that he would put down some rugs to solve the problem.')
# Number of sense-samples: 2
#    - judged_meaning: a metallic tapping sound
#    - judged_meaning: any of two families of small parasitic arachnids with barbed proboscis; feed on blood of warm-blooded animals
#
# Story key: ('tick', 'Tom settled into his new cabin deep in the woods, excited for some peace and quiet. The old floorboards creaked whenever he walked over them. During the night, an odd noise kept echoing through the silent room.', 'He was up all night because of the tick.', 'He could feel them eating his flesh at night; it was horrific.')
# Number of sense-samples: 2
#    - judged_meaning: a metallic tapping sound
#    - judged_meaning: any of two families of small parasitic arachnids with barbed proboscis; feed on blood of warm-blooded animals
#
# Story key: ('tick', 'Tom settled into his new cabin deep in the woods, excited for some peace and quiet. The old floorboards creaked whenever he walked over them. During the night, an odd noise kept echoing through the silent room.', 'He was up all night because of the tick.', '')
# Number of sense-samples: 2
#    - judged_meaning: a metallic tapping sound
#    - judged_meaning: any of two families of small parasitic arachnids with barbed proboscis; feed on blood of warm-blooded animals
#
# Story key: ('palms', 'Jack and Emma arrived at the park early in the morning. They walked slowly, admiring the scenery. Emma paused and pointed out something interesting nearby.', 'She took a photo of the palms.', 'She wanted a photo of the monster insect before it flew away.')
# Number of sense-samples: 2
#    - judged_meaning: the inner surface of the hand from the wrist to the base of the fingers
#    - judged_meaning: any plant of the family Palmae having an unbranched trunk crowned by large pinnate or palmate leaves
#
# Story key: ('palms', 'Jack and Emma arrived at the park early in the morning. They walked slowly, admiring the scenery. Emma paused and pointed out something interesting nearby.', 'She took a photo of the palms.', 'They were green and such a beautiful scenery.')
# Number of sense-samples: 2
#    - judged_meaning: the inner surface of the hand from the wrist to the base of the fingers
#    - judged_meaning: any plant of the family Palmae having an unbranched trunk crowned by large pinnate or palmate leaves
#
# Story key: ('palms', 'Jack and Emma arrived at the park early in the morning. They walked slowly, admiring the scenery. Emma paused and pointed out something interesting nearby.', 'She took a photo of the palms.', '')
# Number of sense-samples: 2
#    - judged_meaning: the inner surface of the hand from the wrist to the base of the fingers
#    - judged_meaning: any plant of the family Palmae having an unbranched trunk crowned by large pinnate or palmate leaves
#
# Story key: ('class', 'Lila received an invitation to an exclusive gathering. She knew it would be held at a grand estate. Curiosity led her to accept and see who would be there.', 'When attending the function at the stately home, she noticed the class of people there.', 'She was shocked to see the number of people there, but decided to walk over and have a talk with them.')
# Number of sense-samples: 2
#    - judged_meaning: a body of students who are taught together
#    - judged_meaning: elegance in dress or behavior
#
# Story key: ('class', 'Lila received an invitation to an exclusive gathering. She knew it would be held at a grand estate. Curiosity led her to accept and see who would be there.', 'When attending the function at the stately home, she noticed the class of people there.', "She was glad she'd bought a fancy dress and hat before the day.")
# Number of sense-samples: 2
#    - judged_meaning: a body of students who are taught together
#    - judged_meaning: elegance in dress or behavior
#
# Story key: ('class', 'Lila received an invitation to an exclusive gathering. She knew it would be held at a grand estate. Curiosity led her to accept and see who would be there.', 'When attending the function at the stately home, she noticed the class of people there.', '')
# Number of sense-samples: 2
#    - judged_meaning: a body of students who are taught together
#    - judged_meaning: elegance in dress or behavior
#
# Story key: ('class', 'Students gathered in anticipation, eager to see what the day would bring. Mrs. Thompson always maintained a high standard in her lessons. Her unique approach and style set her apart from other teachers.', "The teacher's class was known for being distinguished.", 'As she required such a high standard from all of her pupils.')
# Number of sense-samples: 2
#    - judged_meaning: a body of students who are taught together
#    - judged_meaning: elegance in dress or behavior
#
# Story key: ('class', 'Students gathered in anticipation, eager to see what the day would bring. Mrs. Thompson always maintained a high standard in her lessons. Her unique approach and style set her apart from other teachers.', "The teacher's class was known for being distinguished.", 'She dressed very well even in normal school lessons, and took great pride in how she looked.')
# Number of sense-samples: 2
#    - judged_meaning: a body of students who are taught together
#    - judged_meaning: elegance in dress or behavior
#
# Story key: ('class', 'Students gathered in anticipation, eager to see what the day would bring. Mrs. Thompson always maintained a high standard in her lessons. Her unique approach and style set her apart from other teachers.', "The teacher's class was known for being distinguished.", '')
# Number of sense-samples: 2
#    - judged_meaning: a body of students who are taught together
#    - judged_meaning: elegance in dress or behavior
#
# Story key: ('speakers', 'Dan sat at the back of the crowded hall. He watched as the panelists took their seats on stage. Everyone settled in, eagerly anticipating the start.', 'The speakers are too loud.', 'They were trying too hard to get their views across.')
# Number of sense-samples: 2
#    - judged_meaning: someone who expresses in language; someone who talks (especially someone who delivers a public speech or someone especially garrulous)
#    - judged_meaning: electro-acoustic transducer that converts electrical signals into sounds loud enough to be heard at a distance
#
# Story key: ('speakers', 'Dan sat at the back of the crowded hall. He watched as the panelists took their seats on stage. Everyone settled in, eagerly anticipating the start.', 'The speakers are too loud.', 'They were so loud that the audience left the hall with severe headaches.')
# Number of sense-samples: 2
#    - judged_meaning: someone who expresses in language; someone who talks (especially someone who delivers a public speech or someone especially garrulous)
#    - judged_meaning: electro-acoustic transducer that converts electrical signals into sounds loud enough to be heard at a distance
#
# Story key: ('speakers', 'Dan sat at the back of the crowded hall. He watched as the panelists took their seats on stage. Everyone settled in, eagerly anticipating the start.', 'The speakers are too loud.', '')
# Number of sense-samples: 2
#    - judged_meaning: someone who expresses in language; someone who talks (especially someone who delivers a public speech or someone especially garrulous)
#    - judged_meaning: electro-acoustic transducer that converts electrical signals into sounds loud enough to be heard at a distance
#
# Story key: ('material', "Kate had a big project to finish by the end of the week. She was given a package that seemed important. Inside, she found some useful pieces but wasn't exactly sure about their purpose.", "Kate wasn't sure what to do with the material she had been given.", 'Surely if she writes well and uses it properly, the NYT will definitely pick it up.')
# Number of sense-samples: 2
#    - judged_meaning: information (data or ideas or observations) that can be used or reworked into a finished form
#    - judged_meaning: artifact made by weaving or felting or knitting or crocheting natural or synthetic fibers
#
# Story key: ('material', "Kate had a big project to finish by the end of the week. She was given a package that seemed important. Inside, she found some useful pieces but wasn't exactly sure about their purpose.", "Kate wasn't sure what to do with the material she had been given.", 'She was sure that she could think of something to make soon; she just needed some ideas.')
# Number of sense-samples: 2
#    - judged_meaning: information (data or ideas or observations) that can be used or reworked into a finished form
#    - judged_meaning: artifact made by weaving or felting or knitting or crocheting natural or synthetic fibers
#
# Story key: ('material', "Kate had a big project to finish by the end of the week. She was given a package that seemed important. Inside, she found some useful pieces but wasn't exactly sure about their purpose.", "Kate wasn't sure what to do with the material she had been given.", '')
# Number of sense-samples: 2
#    - judged_meaning: information (data or ideas or observations) that can be used or reworked into a finished form
#    - judged_meaning: artifact made by weaving or felting or knitting or crocheting natural or synthetic fibers
#
# Story key: ('materials', 'James was known for his attention to detail in every project. He often spent hours researching and gathering everything he might need. His workshop was filled with various items and reference books, ready for any task.', "He carefully selected materials to enhance the project's quality.", 'James was recognized for his performance at the dinner night.')
# Number of sense-samples: 2
#    - judged_meaning: information (data or ideas or observations) that can be used or reworked into a finished form
#    - judged_meaning: artifact made by weaving or felting or knitting or crocheting natural or synthetic fibers
#
# Story key: ('materials', 'James was known for his attention to detail in every project. He often spent hours researching and gathering everything he might need. His workshop was filled with various items and reference books, ready for any task.', "He carefully selected materials to enhance the project's quality.", 'Wrapping the fabric around the model he had made finished the project off nicely.')
# Number of sense-samples: 2
#    - judged_meaning: information (data or ideas or observations) that can be used or reworked into a finished form
#    - judged_meaning: artifact made by weaving or felting or knitting or crocheting natural or synthetic fibers
#
# Story key: ('materials', 'James was known for his attention to detail in every project. He often spent hours researching and gathering everything he might need. His workshop was filled with various items and reference books, ready for any task.', "He carefully selected materials to enhance the project's quality.", '')
# Number of sense-samples: 2
#    - judged_meaning: information (data or ideas or observations) that can be used or reworked into a finished form
#    - judged_meaning: artifact made by weaving or felting or knitting or crocheting natural or synthetic fibers
#
# Story key: ('material', 'The designers gathered around the table, staring at the blank sheets. They had been given a new project with a looming deadline. The client expected something innovative, yet specific guidelines were minimal.', 'It was hard to know what to do, as they had no material to work with.', 'They were stuck.')
# Number of sense-samples: 2
#    - judged_meaning: information (data or ideas or observations) that can be used or reworked into a finished form
#    - judged_meaning: artifact made by weaving or felting or knitting or crocheting natural or synthetic fibers
#
# Story key: ('material', 'The designers gathered around the table, staring at the blank sheets. They had been given a new project with a looming deadline. The client expected something innovative, yet specific guidelines were minimal.', 'It was hard to know what to do, as they had no material to work with.', 'No leather, no cotton, no felt, or silk, or satin; there was nothing available at all.')
# Number of sense-samples: 2
#    - judged_meaning: information (data or ideas or observations) that can be used or reworked into a finished form
#    - judged_meaning: artifact made by weaving or felting or knitting or crocheting natural or synthetic fibers
#
# Story key: ('material', 'The designers gathered around the table, staring at the blank sheets. They had been given a new project with a looming deadline. The client expected something innovative, yet specific guidelines were minimal.', 'It was hard to know what to do, as they had no material to work with.', '')
# Number of sense-samples: 2
#    - judged_meaning: information (data or ideas or observations) that can be used or reworked into a finished form
#    - judged_meaning: artifact made by weaving or felting or knitting or crocheting natural or synthetic fibers
#
# Story key: ('material', 'Anna had been planning her project for weeks. She gathered all her supplies and set them on the table. Today was the day she would finally start.', 'She spread the new material across the table before beginning her project.', 'She found it helpful to be able to see all of her notes and Post-its at once.')
# Number of sense-samples: 2
#    - judged_meaning: information (data or ideas or observations) that can be used or reworked into a finished form
#    - judged_meaning: artifact made by weaving or felting or knitting or crocheting natural or synthetic fibers
#
# Story key: ('material', 'Anna had been planning her project for weeks. She gathered all her supplies and set them on the table. Today was the day she would finally start.', 'She spread the new material across the table before beginning her project.', 'A fabric that is nice to touch.')
# Number of sense-samples: 2
#    - judged_meaning: information (data or ideas or observations) that can be used or reworked into a finished form
#    - judged_meaning: artifact made by weaving or felting or knitting or crocheting natural or synthetic fibers
#
# ...
#    - judged_meaning: a hand-operated electronic device that controls the coordinates of a cursor on your computer screen as you move it around on a pad; on the bottom of the device is a ball that rolls on the surface of the pad
#
# Story key: ('mouse', "Tom sat at his desk, deep in thought. He glanced at the table where there were crumbs from the sandwich he'd eaten earlier. Something shifted slightly near the edge, catching his eye.", 'The mouse had a mind of its own.', 'He reached out to move the little device so he could click the button.')
# Number of sense-samples: 2
#    - judged_meaning: any of numerous small rodents typically resembling diminutive rats having pointed snouts and small ears on elongated bodies with slender usually hairless tails
#    - judged_meaning: a hand-operated electronic device that controls the coordinates of a cursor on your computer screen as you move it around on a pad; on the bottom of the device is a ball that rolls on the surface of the pad
#
# Story key: ('mouse', "Tom sat at his desk, deep in thought. He glanced at the table where there were crumbs from the sandwich he'd eaten earlier. Something shifted slightly near the edge, catching his eye.", 'The mouse had a mind of its own.', '')
# Number of sense-samples: 2
#    - judged_meaning: any of numerous small rodents typically resembling diminutive rats having pointed snouts and small ears on elongated bodies with slender usually hairless tails
#    - judged_meaning: a hand-operated electronic device that controls the coordinates of a cursor on your computer screen as you move it around on a pad; on the bottom of the device is a ball that rolls on the surface of the pad
#
# Story key: ('steps', 'John was running late for the meeting that could change his career. He grabbed his briefcase, hoping he had everything he needed. The place was not far, but he knew he had to make quick decisions to get there on time.', 'He took steps to the place he needed to get to.', 'They were slippery after a night of heavy rain. He had to tread carefully.')
# Number of sense-samples: 2
#    - judged_meaning: support consisting of a place to rest the foot while ascending or descending a stairway
#    - judged_meaning: any maneuver made as part of progress toward a goal
#
# Story key: ('steps', 'John was running late for the meeting that could change his career. He grabbed his briefcase, hoping he had everything he needed. The place was not far, but he knew he had to make quick decisions to get there on time.', 'He took steps to the place he needed to get to.', 'He decided to take a taxi in order to get there quickly.')
# Number of sense-samples: 2
#    - judged_meaning: support consisting of a place to rest the foot while ascending or descending a stairway
#    - judged_meaning: any maneuver made as part of progress toward a goal
#
# Story key: ('steps', 'John was running late for the meeting that could change his career. He grabbed his briefcase, hoping he had everything he needed. The place was not far, but he knew he had to make quick decisions to get there on time.', 'He took steps to the place he needed to get to.', '')
# Number of sense-samples: 2
#    - judged_meaning: support consisting of a place to rest the foot while ascending or descending a stairway
#    - judged_meaning: any maneuver made as part of progress toward a goal
#
# Story key: ('steps', 'John woke up early to prepare for his day. He had a clear plan in mind and knew exactly where he wanted to go. Standing at the front door, he took a moment to gather his thoughts.', 'There were several steps in his walk.', 'Sometimes, when he was in a hurry, he would skip down, but the surface was wet and icy, so he descended slowly.')
# Number of sense-samples: 2
#    - judged_meaning: a flight of stairs or a flight of steps
#    - judged_meaning: any maneuver made as part of progress toward a goal
#
# Story key: ('steps', 'John woke up early to prepare for his day. He had a clear plan in mind and knew exactly where he wanted to go. Standing at the front door, he took a moment to gather his thoughts.', 'There were several steps in his walk.', 'He formulated a plan in his mind in order to reach his goal.')
# Number of sense-samples: 2
#    - judged_meaning: a flight of stairs or a flight of steps
#    - judged_meaning: any maneuver made as part of progress toward a goal
#
# Story key: ('steps', 'John woke up early to prepare for his day. He had a clear plan in mind and knew exactly where he wanted to go. Standing at the front door, he took a moment to gather his thoughts.', 'There were several steps in his walk.', '')
# Number of sense-samples: 2
#    - judged_meaning: a flight of stairs or a flight of steps
#    - judged_meaning: any maneuver made as part of progress toward a goal
#
# Story key: ('step', 'The woman was determined to help her son succeed. He struggled with both challenges and changes in his life. She knew it was crucial to guide him through the process carefully.', 'The woman asked her son to take each step one at a time.', 'The route up to the attic was a treacherous one.')
# Number of sense-samples: 2
#    - judged_meaning: a flight of stairs or a flight of steps
#    - judged_meaning: any maneuver made as part of progress toward a goal
#
# Story key: ('step', 'The woman was determined to help her son succeed. He struggled with both challenges and changes in his life. She knew it was crucial to guide him through the process carefully.', 'The woman asked her son to take each step one at a time.', 'She advised him to focus on one small task at a time to reach his big dream.')
# Number of sense-samples: 2
#    - judged_meaning: a flight of stairs or a flight of steps
#    - judged_meaning: any maneuver made as part of progress toward a goal
#
# Story key: ('step', 'The woman was determined to help her son succeed. He struggled with both challenges and changes in his life. She knew it was crucial to guide him through the process carefully.', 'The woman asked her son to take each step one at a time.', '')
# Number of sense-samples: 2
#    - judged_meaning: a flight of stairs or a flight of steps
#    - judged_meaning: any maneuver made as part of progress toward a goal
#
# Story key: ('steps', 'Sarah had been waiting at the airport for hours. Her connecting flight was delayed due to bad weather. She was determined to reach her destination no matter what.', 'The woman had taken steps to get on the flight.', 'She ran up them quickly and wasted no time.')
# Number of sense-samples: 2
#    - judged_meaning: a flight of stairs or a flight of steps
#    - judged_meaning: any maneuver made as part of progress toward a goal
#
# Story key: ('steps', 'Sarah had been waiting at the airport for hours. Her connecting flight was delayed due to bad weather. She was determined to reach her destination no matter what.', 'The woman had taken steps to get on the flight.', 'She spoke to the airline staff, rearranged her booking, and kept checking for any open seats that might get her there sooner.')
# Number of sense-samples: 2
#    - judged_meaning: a flight of stairs or a flight of steps
#    - judged_meaning: any maneuver made as part of progress toward a goal
#
# Story key: ('steps', 'Sarah had been waiting at the airport for hours. Her connecting flight was delayed due to bad weather. She was determined to reach her destination no matter what.', 'The woman had taken steps to get on the flight.', '')
# Number of sense-samples: 2
#    - judged_meaning: a flight of stairs or a flight of steps
#    - judged_meaning: any maneuver made as part of progress toward a goal
#
# Story key: ('steps', 'John had a big job interview in the city. He left his house early to ensure he had enough time. Along the way, he faced several obstacles but remained determined.', 'He took all the steps he needed to get to where he was going.', 'He was very disciplined.')
# Number of sense-samples: 2
#    - judged_meaning: any maneuver made as part of progress toward a goal
#    - judged_meaning: support consisting of a place to rest the foot while ascending or descending a stairway
#
# Story key: ('steps', 'John had a big job interview in the city. He left his house early to ensure he had enough time. Along the way, he faced several obstacles but remained determined.', 'He took all the steps he needed to get to where he was going.', 'He had to be careful, as he had recently fallen and hurt his leg.')
# Number of sense-samples: 2
#    - judged_meaning: any maneuver made as part of progress toward a goal
#    - judged_meaning: support consisting of a place to rest the foot while ascending or descending a stairway
#
# Story key: ('steps', 'John had a big job interview in the city. He left his house early to ensure he had enough time. Along the way, he faced several obstacles but remained determined.', 'He took all the steps he needed to get to where he was going.', '')
# Number of sense-samples: 2
#    - judged_meaning: any maneuver made as part of progress toward a goal
#    - judged_meaning: support consisting of a place to rest the foot while ascending or descending a stairway
#
# Story key: ('steps', 'The old manor stood on the hill, looking as mysterious as ever. Two curious friends decided to explore its secrets one sunny afternoon. They entered cautiously, eager to uncover its hidden past.', 'They took several steps to get to where they wanted.', 'Their hard work and best efforts paid off; they found a room full of treasure!')
# Number of sense-samples: 2
#    - judged_meaning: any maneuver made as part of progress toward a goal
#    - judged_meaning: support consisting of a place to rest the foot while ascending or descending a stairway
#
# Story key: ('steps', 'The old manor stood on the hill, looking as mysterious as ever. Two curious friends decided to explore its secrets one sunny afternoon. They entered cautiously, eager to uncover its hidden past.', 'They took several steps to get to where they wanted.', 'The journey was not easy, and it never will be.')
# Number of sense-samples: 2
#    - judged_meaning: any maneuver made as part of progress toward a goal
#    - judged_meaning: support consisting of a place to rest the foot while ascending or descending a stairway
#
# Story key: ('steps', 'The old manor stood on the hill, looking as mysterious as ever. Two curious friends decided to explore its secrets one sunny afternoon. They entered cautiously, eager to uncover its hidden past.', 'They took several steps to get to where they wanted.', '')
# Number of sense-samples: 2
#    - judged_meaning: any maneuver made as part of progress toward a goal
#    - judged_meaning: support consisting of a place to rest the foot while ascending or descending a stairway
#
# Story key: ('dough', 'John had always been meticulous with his hands. Every day, he laid everything out on the table just so. Today, he was determined to make something perfect.', 'He carefully looked at the dough.', 'And when he was done, it was nothing short of perfect!')
# Number of sense-samples: 2
#    - judged_meaning: a flour mixture stiff enough to knead or roll
#    - judged_meaning: informal terms for money
#
# Story key: ('dough', 'John had always been meticulous with his hands. Every day, he laid everything out on the table just so. Today, he was determined to make something perfect.', 'He carefully looked at the dough.', 'He realized that he would have to get some more money from the cash point later in the day.')
# Number of sense-samples: 2
#    - judged_meaning: a flour mixture stiff enough to knead or roll
#    - judged_meaning: informal terms for money
#
# Story key: ('dough', 'John had always been meticulous with his hands. Every day, he laid everything out on the table just so. Today, he was determined to make something perfect.', 'He carefully looked at the dough.', '')
# Number of sense-samples: 2
#    - judged_meaning: a flour mixture stiff enough to knead or roll
#    - judged_meaning: informal terms for money
#
# Story key: ('dough', 'Emma and Jake had been saving up for months for their big plan. They spent the whole afternoon preparing everything they needed. The excitement in the air was tangible as they gathered their supplies.', "They were very devastated because they didn't have any more dough left.", 'They would have to make more with what flour they had left.')
# Number of sense-samples: 2
#    - judged_meaning: a flour mixture stiff enough to knead or roll
#    - judged_meaning: informal terms for money
#
# Story key: ('dough', 'Emma and Jake had been saving up for months for their big plan. They spent the whole afternoon preparing everything they needed. The excitement in the air was tangible as they gathered their supplies.', "They were very devastated because they didn't have any more dough left.", 'As they reached their wallet, they noticed that they had to earn more to make their dream become a reality.')
# Number of sense-samples: 2
#    - judged_meaning: a flour mixture stiff enough to knead or roll
#    - judged_meaning: informal terms for money
#
# Story key: ('dough', 'Emma and Jake had been saving up for months for their big plan. They spent the whole afternoon preparing everything they needed. The excitement in the air was tangible as they gathered their supplies.', "They were very devastated because they didn't have any more dough left.", '')
# Number of sense-samples: 2
#    - judged_meaning: a flour mixture stiff enough to knead or roll
#    - judged_meaning: informal terms for money
#
# Story key: ('dough', 'The family gathered around the small table, looking hopeful. With the fridge nearly empty, they needed to come up with a plan. Mom looked at Dad with a knowing smile.', 'Having enough dough will satisfy the whole family.', 'She sent Dad out to the shops to secure some stiff flour mixture.')
# Number of sense-samples: 2
#    - judged_meaning: a flour mixture stiff enough to knead or roll
#    - judged_meaning: informal terms for money
#
# Story key: ('dough', 'The family gathered around the small table, looking hopeful. With the fridge nearly empty, they needed to come up with a plan. Mom looked at Dad with a knowing smile.', 'Having enough dough will satisfy the whole family.', 'Then, we can buy whatever we want for dinner.')
# Number of sense-samples: 2
#    - judged_meaning: a flour mixture stiff enough to knead or roll
#    - judged_meaning: informal terms for money
#
# Story key: ('dough', 'The family gathered around the small table, looking hopeful. With the fridge nearly empty, they needed to come up with a plan. Mom looked at Dad with a knowing smile.', 'Having enough dough will satisfy the whole family.', '')
# Number of sense-samples: 2
#    - judged_meaning: a flour mixture stiff enough to knead or roll
#    - judged_meaning: informal terms for money
#
# Story key: ('dough', 'Tom stood at the counter, looking at the ingredients scattered before him. He had already spent most of his savings on this new venture. His friend, Jim, promised to help him figure things out.', 'Does he have more dough available?', 'Only time will tell if his loaves are good enough.')
# Number of sense-samples: 2
#    - judged_meaning: a flour mixture stiff enough to knead or roll
#    - judged_meaning: informal terms for money
#
# Story key: ('dough', 'Tom stood at the counter, looking at the ingredients scattered before him. He had already spent most of his savings on this new venture. His friend, Jim, promised to help him figure things out.', 'Does he have more dough available?', 'He wondered if this new venture would result in his having to sell his car.')
# Number of sense-samples: 2
#    - judged_meaning: a flour mixture stiff enough to knead or roll
#    - judged_meaning: informal terms for money
#
# Story key: ('dough', 'Tom stood at the counter, looking at the ingredients scattered before him. He had already spent most of his savings on this new venture. His friend, Jim, promised to help him figure things out.', 'Does he have more dough available?', '')
# Number of sense-samples: 2
#    - judged_meaning: a flour mixture stiff enough to knead or roll
#    - judged_meaning: informal terms for money

# %%
sense_pairs = {}

for story_key, items in story_groups.items():
    senses = list({s["judged_meaning"] for s in items})

    sense_pairs[story_key] = senses

print("Number of story setups:", len(sense_pairs))
# Out:
# Number of story setups: 1140

# %%
for story_key, senses in sense_pairs.items():
    print("\n==============================")
    print("Story:", story_key)
    print("Found senses:")
    for s in senses:
        print("  •", s)
# Out:
# ==============================
# Story: ('potential', 'The old machine hummed in the corner of the workshop. Clara examined its dusty dials with a furrowed brow. She wondered if it could be brought back to life.', "The potential couldn't be measured.", 'She collected a battery reader and looked on earnestly, willing some life back into the old machine.')
# Found senses:
#   • the difference in electrical charge between two points in a circuit expressed in volts
#   • the inherent capacity for coming into being
#
# ==============================
# Story: ('potential', 'The old machine hummed in the corner of the workshop. Clara examined its dusty dials with a furrowed brow. She wondered if it could be brought back to life.', "The potential couldn't be measured.", 'The machine could make such wonderful clothing if it were in working order.')
# Found senses:
#   • the difference in electrical charge between two points in a circuit expressed in volts
#   • the inherent capacity for coming into being
#
# ==============================
# Story: ('potential', 'The old machine hummed in the corner of the workshop. Clara examined its dusty dials with a furrowed brow. She wondered if it could be brought back to life.', "The potential couldn't be measured.", '')
# Found senses:
#   • the difference in electrical charge between two points in a circuit expressed in volts
#   • the inherent capacity for coming into being
#
# ==============================
# Story: ('base', 'The troops were stationed at a remote camp for training. To pass the time, they often engaged in recreational sports. One afternoon, they decided to play a game on the field next to their tents.', 'The soldiers were playing a bat and ball game, which involved them running towards the base.', 'Unfortunately, the sentries saw them approaching and shot them all dead.')
# Found senses:
#   • a place that the runner must touch before scoring
#   • installation from which a military force initiates operations
#
# ==============================
# Story: ('base', 'The troops were stationed at a remote camp for training. To pass the time, they often engaged in recreational sports. One afternoon, they decided to play a game on the field next to their tents.', 'The soldiers were playing a bat and ball game, which involved them running towards the base.', "It didn't take long for the winning team to get a home run.")
# Found senses:
#   • a place that the runner must touch before scoring
#   • installation from which a military force initiates operations
#
# ==============================
# Story: ('base', 'The troops were stationed at a remote camp for training. To pass the time, they often engaged in recreational sports. One afternoon, they decided to play a game on the field next to their tents.', 'The soldiers were playing a bat and ball game, which involved them running towards the base.', '')
# Found senses:
#   • a place that the runner must touch before scoring
#   • installation from which a military force initiates operations
#
# ==============================
# Story: ('driving', 'Poppy had a unique impact on her friends. They often found themselves doing things they never planned to do. Her enthusiasm was hard to resist, no matter how hesitant they felt.', "Poppy was always driving her friends, although they wished she wouldn't.", 'Just for once, she wished that her friends would plan a get-together or adventure, and she could enjoy being present.')
# Found senses:
#   • operate or control a vehicle
#   • to compel or force or urge relentlessly or exert coercive pressure on, or motivate strongly
#
# ==============================
# Story: ('driving', 'Poppy had a unique impact on her friends. They often found themselves doing things they never planned to do. Her enthusiasm was hard to resist, no matter how hesitant they felt.', "Poppy was always driving her friends, although they wished she wouldn't.", 'Poppy would be the one to take them from their houses to events and restaurants.')
# Found senses:
#   • operate or control a vehicle
#   • to compel or force or urge relentlessly or exert coercive pressure on, or motivate strongly
#
# ==============================
# Story: ('driving', 'Poppy had a unique impact on her friends. They often found themselves doing things they never planned to do. Her enthusiasm was hard to resist, no matter how hesitant they felt.', "Poppy was always driving her friends, although they wished she wouldn't.", '')
# Found senses:
#   • operate or control a vehicle
#   • to compel or force or urge relentlessly or exert coercive pressure on, or motivate strongly
#
# ==============================
# Story: ('drive', 'John glanced at his watch and sighed. It had been a busy afternoon filled with back-to-back meetings. The evening sky was beginning to darken as he packed up his bag.', 'He was ready to drive after a long day.', "He started the car, and the engine roared to life. He sped off down the country lanes into the sunset; he'd been waiting for this moment all day.")
# Found senses:
#   • a journey in a vehicle (usually an automobile)
#   • hitting a golf ball off of a tee with a driver
#
# ==============================
# Story: ('drive', 'John glanced at his watch and sighed. It had been a busy afternoon filled with back-to-back meetings. The evening sky was beginning to darken as he packed up his bag.', 'He was ready to drive after a long day.', "As he settled into his car, he couldn't help but think about the satisfying feeling of sending the ball soaring down the fairway during his weekend games.")
# Found senses:
#   • a journey in a vehicle (usually an automobile)
#   • hitting a golf ball off of a tee with a driver
#
# ==============================
# Story: ('drive', 'John glanced at his watch and sighed. It had been a busy afternoon filled with back-to-back meetings. The evening sky was beginning to darken as he packed up his bag.', 'He was ready to drive after a long day.', '')
# Found senses:
#   • a journey in a vehicle (usually an automobile)
#   • hitting a golf ball off of a tee with a driver
#
# ==============================
# Story: ('drive', "Tom woke up early that morning. He had been looking forward to today for weeks. As he got ready, he couldn't stop thinking about what lay ahead.", 'That was a good drive.', 'He put on his driving gloves and was ready.')
# Found senses:
#   • a journey in a vehicle (usually an automobile)
#   • hitting a golf ball off of a tee with a driver
#
# ==============================
# Story: ('drive', "Tom woke up early that morning. He had been looking forward to today for weeks. As he got ready, he couldn't stop thinking about what lay ahead.", 'That was a good drive.', 'Tom was proud of how his golf game was going.')
# Found senses:
#   • a journey in a vehicle (usually an automobile)
#   • hitting a golf ball off of a tee with a driver
#
# ==============================
# Story: ('drive', "Tom woke up early that morning. He had been looking forward to today for weeks. As he got ready, he couldn't stop thinking about what lay ahead.", 'That was a good drive.', '')
# Found senses:
#   • a journey in a vehicle (usually an automobile)
#   • hitting a golf ball off of a tee with a driver
#
# ==============================
# Story: ('drive', 'Jack packed his bags and left the house early. The weather was perfect for the day ahead. He was eager to test his skills and patience.', 'The drive was a good distance.', 'After hours on the road, Jack finally arrived at his destination, ready to face the challenges of the day.')
# Found senses:
#   • a journey in a vehicle (usually an automobile)
#   • hitting a golf ball off of a tee with a driver
#
# ==============================
# Story: ('drive', 'Jack packed his bags and left the house early. The weather was perfect for the day ahead. He was eager to test his skills and patience.', 'The drive was a good distance.', 'He was excited to see how far he could hit the ball.')
# Found senses:
#   • a journey in a vehicle (usually an automobile)
#   • hitting a golf ball off of a tee with a driver
#
# ==============================
# Story: ('drive', 'Jack packed his bags and left the house early. The weather was perfect for the day ahead. He was eager to test his skills and patience.', 'The drive was a good distance.', '')
# Found senses:
#   • a journey in a vehicle (usually an automobile)
#   • hitting a golf ball off of a tee with a driver
#
# ==============================
# Story: ('drive', 'Lisa had always been competitive. Every weekend, she dedicated herself to her passion. She believed that her relentless practice would pay off someday.', 'Her drive was what ultimately got her into the top university.', 'She made that long trip to show the course coordinators her dedication to going to that university, and they said that was one of the reasons why they accepted her.')
# Found senses:
#   • a journey in a vehicle (usually an automobile)
#   • hitting a golf ball off of a tee with a driver
#
# ==============================
# Story: ('drive', 'Lisa had always been competitive. Every weekend, she dedicated herself to her passion. She believed that her relentless practice would pay off someday.', 'Her drive was what ultimately got her into the top university.', 'She felt immensely proud of herself.')
# Found senses:
#   • a journey in a vehicle (usually an automobile)
#   • hitting a golf ball off of a tee with a driver
#
# ==============================
# Story: ('drive', 'Lisa had always been competitive. Every weekend, she dedicated herself to her passion. She believed that her relentless practice would pay off someday.', 'Her drive was what ultimately got her into the top university.', '')
# Found senses:
#   • a journey in a vehicle (usually an automobile)
#   • hitting a golf ball off of a tee with a driver
#
# ==============================
# Story: ('front', 'It was a gray morning, and everyone in town braced themselves for the coming change. The sky darkened as the day went on, casting an eerie shadow over the old buildings. People gathered at the edge of the street, whispering about what was approaching.', 'The front was something to behold.', 'It heralded a huge storm.')
# Found senses:
#   • (meteorology) the atmospheric phenomenon created at the boundary between two different air masses
#   • the side that is forward or prominent
#
# ==============================
# Story: ('front', 'It was a gray morning, and everyone in town braced themselves for the coming change. The sky darkened as the day went on, casting an eerie shadow over the old buildings. People gathered at the edge of the street, whispering about what was approaching.', 'The front was something to behold.', 'The buildings seemed almost decrepit as the weather change loomed.')
# Found senses:
#   • (meteorology) the atmospheric phenomenon created at the boundary between two different air masses
#   • the side that is forward or prominent
#
# ==============================
# Story: ('front', 'It was a gray morning, and everyone in town braced themselves for the coming change. The sky darkened as the day went on, casting an eerie shadow over the old buildings. People gathered at the edge of the street, whispering about what was approaching.', 'The front was something to behold.', '')
# Found senses:
#   • (meteorology) the atmospheric phenomenon created at the boundary between two different air masses
#   • the side that is forward or prominent
#
# ==============================
# Story: ('appendix', 'John had always been curious about things that stood out. Whether it was a rare book at the library or a peculiar x-ray from his anatomy class, he would spend hours examining them. One day, he stumbled upon something unusual that caught his attention.', 'The appendix was so different, one could notice it instantly.', 'The author had written them in bold font as if he wanted people to notice them.')
# Found senses:
#   • a vestigial process that extends from the lower end of the cecum and that resembles a small pouch
#   • supplementary material that is collected and appended at the back of a book
#
# ==============================
# Story: ('appendix', 'John had always been curious about things that stood out. Whether it was a rare book at the library or a peculiar x-ray from his anatomy class, he would spend hours examining them. One day, he stumbled upon something unusual that caught his attention.', 'The appendix was so different, one could notice it instantly.', 'He was so captivated by the uniqueness that he decided to carry out research before treatment.')
# Found senses:
#   • a vestigial process that extends from the lower end of the cecum and that resembles a small pouch
#   • supplementary material that is collected and appended at the back of a book
#
# ==============================
# Story: ('appendix', 'John had always been curious about things that stood out. Whether it was a rare book at the library or a peculiar x-ray from his anatomy class, he would spend hours examining them. One day, he stumbled upon something unusual that caught his attention.', 'The appendix was so different, one could notice it instantly.', '')
# Found senses:
#   • a vestigial process that extends from the lower end of the cecum and that resembles a small pouch
#   • supplementary material that is collected and appended at the back of a book
#
# ==============================
# Story: ('appendix', 'John had been working on his novel for months, pouring over every chapter. He was determined to have it completed by the end of the week. However, there had been an unexpected delay in his progress.', 'John was late completing the book because he had been having trouble with his appendix.', "He wasn't sure if he should reference all the other research articles that had been used in putting his novel together with such accuracy.")
# Found senses:
#   • a vestigial process that extends from the lower end of the cecum and that resembles a small pouch
#   • supplementary material that is collected and appended at the back of a book
#
# ==============================
# Story: ('appendix', 'John had been working on his novel for months, pouring over every chapter. He was determined to have it completed by the end of the week. However, there had been an unexpected delay in his progress.', 'John was late completing the book because he had been having trouble with his appendix.', 'It had been causing him a lot of pain in his lower abdomen recently.')
# Found senses:
#   • a vestigial process that extends from the lower end of the cecum and that resembles a small pouch
#   • supplementary material that is collected and appended at the back of a book
#
# ==============================
# Story: ('appendix', 'John had been working on his novel for months, pouring over every chapter. He was determined to have it completed by the end of the week. However, there had been an unexpected delay in his progress.', 'John was late completing the book because he had been having trouble with his appendix.', '')
# Found senses:
#   • a vestigial process that extends from the lower end of the cecum and that resembles a small pouch
#   • supplementary material that is collected and appended at the back of a book
#
# ==============================
# Story: ('appendicitis', 'The writer sat at his cluttered desk, surrounded by piles of paper and empty coffee cups. He had been working tirelessly on his latest book, determined to finish it by the looming deadline. However, a dull ache had started to distract him from his work.', 'The writer was struggling with his appendicitis.', 'The only option was to gather the papers in order so he could make a list.')
# Found senses:
#   • a vestigial process that extends from the lower end of the cecum and that resembles a small pouch
#   • supplementary material that is collected and appended at the back of a book
#
# ==============================
# Story: ('appendicitis', 'The writer sat at his cluttered desk, surrounded by piles of paper and empty coffee cups. He had been working tirelessly on his latest book, determined to finish it by the looming deadline. However, a dull ache had started to distract him from his work.', 'The writer was struggling with his appendicitis.', 'He would need to go to the hospital to have the organ removed.')
# Found senses:
#   • a vestigial process that extends from the lower end of the cecum and that resembles a small pouch
#   • supplementary material that is collected and appended at the back of a book
#
# ==============================
# Story: ('appendicitis', 'The writer sat at his cluttered desk, surrounded by piles of paper and empty coffee cups. He had been working tirelessly on his latest book, determined to finish it by the looming deadline. However, a dull ache had started to distract him from his work.', 'The writer was struggling with his appendicitis.', '')
# Found senses:
#   • a vestigial process that extends from the lower end of the cecum and that resembles a small pouch
#   • supplementary material that is collected and appended at the back of a book
#
# ==============================
# Story: ('temple', 'The night was calm and quiet. They walked through the old city streets. The air was filled with a sense of mystery.', 'Their temple glowed in the moonlight.', 'Then, they all bowed down in silence.')
# Found senses:
#   • (Judaism) the place of worship for a Jewish congregation
#   • the flat area on either side of the forehead
#
# ==============================
# Story: ('temple', 'The night was calm and quiet. They walked through the old city streets. The air was filled with a sense of mystery.', 'Their temple glowed in the moonlight.', 'They had to mop the sweat away.')
# Found senses:
#   • (Judaism) the place of worship for a Jewish congregation
#   • the flat area on either side of the forehead
#
# ==============================
# Story: ('temple', 'The night was calm and quiet. They walked through the old city streets. The air was filled with a sense of mystery.', 'Their temple glowed in the moonlight.', '')
# Found senses:
#   • (Judaism) the place of worship for a Jewish congregation
#   • the flat area on either side of the forehead
#
# ==============================
# Story: ('catch', 'John had found an unusual box at the back of the attic. Inside, there were strange trinkets and a dusty old map. He was excited but also a little wary of what he had discovered.', "He couldn't figure out the catch.", 'One thing was clear: his next adventure lay in the mystery of the map.')
# Found senses:
#   • a drawback or difficulty that is not readily evident
#   • the quantity that was caught
#
# ==============================
# Story: ('catch', 'John had found an unusual box at the back of the attic. Inside, there were strange trinkets and a dusty old map. He was excited but also a little wary of what he had discovered.', "He couldn't figure out the catch.", 'He set it aside and called his friend for advice.')
# Found senses:
#   • a drawback or difficulty that is not readily evident
#   • the quantity that was caught
#
# ==============================
# Story: ('catch', 'John had found an unusual box at the back of the attic. Inside, there were strange trinkets and a dusty old map. He was excited but also a little wary of what he had discovered.', "He couldn't figure out the catch.", '')
# Found senses:
#   • a drawback or difficulty that is not readily evident
#   • the quantity that was caught
#
# ==============================
# Story: ('cleanly', 'Jason had prepared for months for the local robotics competition. His robot, EcoBot, was designed to perform complex obstacle courses. The goal was to maneuver smoothly and efficiently through the course while showcasing innovative technology.', 'He exited the competition cleanly, impressing both the judges and the organizers.', "It couldn't have gone any better.")
# Found senses:
#   • in a manner that minimizes dirt and pollution
#   • in an adroit manner
#
# ==============================
# Story: ('cleanly', 'Jason had prepared for months for the local robotics competition. His robot, EcoBot, was designed to perform complex obstacle courses. The goal was to maneuver smoothly and efficiently through the course while showcasing innovative technology.', 'He exited the competition cleanly, impressing both the judges and the organizers.', 'He left no trace of ever being on the course and won first place as a result.')
# Found senses:
#   • in a manner that minimizes dirt and pollution
#   • in an adroit manner
#
# ==============================
# Story: ('cleanly', 'Jason had prepared for months for the local robotics competition. His robot, EcoBot, was designed to perform complex obstacle courses. The goal was to maneuver smoothly and efficiently through the course while showcasing innovative technology.', 'He exited the competition cleanly, impressing both the judges and the organizers.', '')
# Found senses:
#   • in a manner that minimizes dirt and pollution
#   • in an adroit manner
#
# ==============================
# Story: ('cleanly', 'Linda had always been meticulous with her work. Today, she faced her biggest challenge yet: a delicate fabric that required precision. The scissors in her hand felt like an extension of herself. ', 'She sliced through the fabric cleanly, leaving no mess behind.', 'With such precision, there was not any waste of material.')
# Found senses:
#   • in a manner that minimizes dirt and pollution
#   • in an adroit manner
#
# ==============================
# Story: ('cleanly', 'Linda had always been meticulous with her work. Today, she faced her biggest challenge yet: a delicate fabric that required precision. The scissors in her hand felt like an extension of herself. ', 'She sliced through the fabric cleanly, leaving no mess behind.', 'She was relieved, as any sullying of the material would have meant starting again from scratch, which would have been an expensive mistake to make.')
# Found senses:
#   • in a manner that minimizes dirt and pollution
#   • in an adroit manner
#
# ==============================
# Story: ('cleanly', 'Linda had always been meticulous with her work. Today, she faced her biggest challenge yet: a delicate fabric that required precision. The scissors in her hand felt like an extension of herself. ', 'She sliced through the fabric cleanly, leaving no mess behind.', '')
# Found senses:
#   • in a manner that minimizes dirt and pollution
#   • in an adroit manner
#
# ==============================
# Story: ('cleanly', 'The group arrived at the park just before noon with a few picnic baskets. They spread out a large blanket on the grass and set up a small table. Everyone was excited to enjoy the day and have a meal together.', 'They tried to share and serve the food as cleanly as possible.', 'Everyone was given the exact same portions.')
# Found senses:
#   • in a manner that minimizes dirt and pollution
#   • in an adroit manner
#
# ==============================
# Story: ('cleanly', 'The group arrived at the park just before noon with a few picnic baskets. They spread out a large blanket on the grass and set up a small table. Everyone was excited to enjoy the day and have a meal together.', 'They tried to share and serve the food as cleanly as possible.', 'Having paper plates definitely helped everyone at the end of the picnic.')
# Found senses:
#   • in a manner that minimizes dirt and pollution
#   • in an adroit manner
#
# ==============================
# Story: ('cleanly', 'The group arrived at the park just before noon with a few picnic baskets. They spread out a large blanket on the grass and set up a small table. Everyone was excited to enjoy the day and have a meal together.', 'They tried to share and serve the food as cleanly as possible.', '')
# Found senses:
#   • in a manner that minimizes dirt and pollution
#   • in an adroit manner
#
# ==============================
# Story: ('withdrawal', 'John had always been meticulous with his habits. Every morning, he visited the bank or the pharmacy on his way to work. That day, he decided to make a change in his routine.', 'After the sudden withdrawal, he felt anxious and unsteady all day.', 'It felt unsafe to have taken so much money from his account in one go.')
# Found senses:
#   • the act of taking out money or other capital
#   • the termination of drug taking
#
# ==============================
# Story: ('withdrawal', 'John had always been meticulous with his habits. Every morning, he visited the bank or the pharmacy on his way to work. That day, he decided to make a change in his routine.', 'After the sudden withdrawal, he felt anxious and unsteady all day.', 'This was day one of trying to get clean.')
# Found senses:
#   • the act of taking out money or other capital
#   • the termination of drug taking
#
# ==============================
# Story: ('withdrawal', 'John had always been meticulous with his habits. Every morning, he visited the bank or the pharmacy on his way to work. That day, he decided to make a change in his routine.', 'After the sudden withdrawal, he felt anxious and unsteady all day.', '')
# Found senses:
#   • the act of taking out money or other capital
#   • the termination of drug taking
#
# ==============================
# Story: ('withdrawal', 'John sat quietly at the table, staring at the letter in his hands. He remembered the advice his friend had given him, but his mind was still unsettled. The decision had weighed heavily on him for days.', 'The withdrawal was really difficult.', 'He sighed as he walked to the bank, knowing that taking out the money for the investment was a necessary but tough decision.')
# Found senses:
#   • the act of taking out money or other capital
#   • the termination of drug taking
#
# ==============================
# Story: ('withdrawal', 'John sat quietly at the table, staring at the letter in his hands. He remembered the advice his friend had given him, but his mind was still unsettled. The decision had weighed heavily on him for days.', 'The withdrawal was really difficult.', "He couldn't get over the way he was feeling.")
# Found senses:
#   • the act of taking out money or other capital
#   • the termination of drug taking
#
# ==============================
# Story: ('withdrawal', 'John sat quietly at the table, staring at the letter in his hands. He remembered the advice his friend had given him, but his mind was still unsettled. The decision had weighed heavily on him for days.', 'The withdrawal was really difficult.', '')
# Found senses:
#   • the act of taking out money or other capital
#   • the termination of drug taking
#
# ==============================
# Story: ('joke', 'Mary received an unexpected invitation on Wednesday. It was a fancy letter, sealed with a golden sticker and decorated with colorful confetti. Her friends told her it was probably just a prank.', 'She thought that this was one big joke.', "She really couldn't stop laughing.")
# Found senses:
#   • a humorous anecdote or remark intended to provoke laughter
#   • a triviality not to be taken seriously
#
# ==============================
# Story: ('joke', 'Mary received an unexpected invitation on Wednesday. It was a fancy letter, sealed with a golden sticker and decorated with colorful confetti. Her friends told her it was probably just a prank.', 'She thought that this was one big joke.', "She didn't even bother opening it as she, disinterestedly, stuck it in a pile of junk mail and leaflets.")
# Found senses:
#   • a humorous anecdote or remark intended to provoke laughter
#   • a triviality not to be taken seriously
#
# ==============================
# Story: ('joke', 'Mary received an unexpected invitation on Wednesday. It was a fancy letter, sealed with a golden sticker and decorated with colorful confetti. Her friends told her it was probably just a prank.', 'She thought that this was one big joke.', '')
# Found senses:
#   • a humorous anecdote or remark intended to provoke laughter
#   • a triviality not to be taken seriously
#
# ==============================
# Story: ('landing', 'Tom gripped the worn railing as he ascended the staircase, heart pounding with every step. He could hear the whirr of engines echoing faintly in the background. Each creak underfoot brought a growing sense of anticipation.', 'The landing was rough.', 'When he reached the top of the stairs, the crowd cheered.')
# Found senses:
#   • an intermediate platform in a staircase
#   • the act of coming down to the earth (or other surface)
#
# ==============================
# Story: ('landing', 'Tom gripped the worn railing as he ascended the staircase, heart pounding with every step. He could hear the whirr of engines echoing faintly in the background. Each creak underfoot brought a growing sense of anticipation.', 'The landing was rough.', 'The engine slowed to a halt, and he steadied himself against the wall. Soon, he realized that they were no longer in motion.')
# Found senses:
#   • an intermediate platform in a staircase
#   • the act of coming down to the earth (or other surface)
#
# ==============================
# Story: ('landing', 'Tom gripped the worn railing as he ascended the staircase, heart pounding with every step. He could hear the whirr of engines echoing faintly in the background. Each creak underfoot brought a growing sense of anticipation.', 'The landing was rough.', '')
# Found senses:
#   • an intermediate platform in a staircase
#   • the act of coming down to the earth (or other surface)
#
# ==============================
# Story: ('faults', "The explorer gazed out at the vast landscape stretching before him. He marveled at the planet's incredible beauty yet sensed something foreboding. As he ventured further, he couldn't shake the feeling that something was amiss.", 'The Earth has many faults.', "But despite that, we can still appreciate nature's perfect imperfections.")
# Found senses:
#   • the quality of being inadequate or falling short of perfection
#   • (geology) a crack in the earth's crust resulting from the displacement of one side with respect to the other
#
# ==============================
# Story: ('faults', "The explorer gazed out at the vast landscape stretching before him. He marveled at the planet's incredible beauty yet sensed something foreboding. As he ventured further, he couldn't shake the feeling that something was amiss.", 'The Earth has many faults.', 'The landscape lacks the ability to sustain life forms for long.')
# Found senses:
#   • the quality of being inadequate or falling short of perfection
#   • (geology) a crack in the earth's crust resulting from the displacement of one side with respect to the other
#
# ==============================
# Story: ('faults', "The explorer gazed out at the vast landscape stretching before him. He marveled at the planet's incredible beauty yet sensed something foreboding. As he ventured further, he couldn't shake the feeling that something was amiss.", 'The Earth has many faults.', '')
# Found senses:
#   • the quality of being inadequate or falling short of perfection
#   • (geology) a crack in the earth's crust resulting from the displacement of one side with respect to the other
#
# ==============================
# Story: ('degree', 'John always dreamed of being the best scientist. He spent years studying and experimenting tirelessly. His professor noticed his dedication and encouraged him to aim higher.', 'He has to work extremely hard to reach the highest degree in his field.', 'As a result of this, he found a job at an accredited scientific business.')
# Found senses:
#   • an award conferred by a college or university signifying that the recipient has satisfactorily completed a course of study
#   • a position on a scale of intensity or amount or quality
#
# ==============================
# Story: ('degree', 'John always dreamed of being the best scientist. He spent years studying and experimenting tirelessly. His professor noticed his dedication and encouraged him to aim higher.', 'He has to work extremely hard to reach the highest degree in his field.', 'John continued to work hard after finishing his education.')
# Found senses:
#   • an award conferred by a college or university signifying that the recipient has satisfactorily completed a course of study
#   • a position on a scale of intensity or amount or quality
#
# ==============================
# Story: ('degree', 'John always dreamed of being the best scientist. He spent years studying and experimenting tirelessly. His professor noticed his dedication and encouraged him to aim higher.', 'He has to work extremely hard to reach the highest degree in his field.', '')
# Found senses:
#   • an award conferred by a college or university signifying that the recipient has satisfactorily completed a course of study
#   • a position on a scale of intensity or amount or quality
#
# ==============================
# Story: ('tick', 'Tom settled into his new cabin deep in the woods, excited for some peace and quiet. The old floorboards creaked whenever he walked over them. During the night, an odd noise kept echoing through the silent room.', 'He was up all night because of the tick.', 'He decided the following day that he would put down some rugs to solve the problem.')
# Found senses:
#   • a metallic tapping sound
#   • any of two families of small parasitic arachnids with barbed proboscis; feed on blood of warm-blooded animals
#
# ==============================
# Story: ('tick', 'Tom settled into his new cabin deep in the woods, excited for some peace and quiet. The old floorboards creaked whenever he walked over them. During the night, an odd noise kept echoing through the silent room.', 'He was up all night because of the tick.', 'He could feel them eating his flesh at night; it was horrific.')
# Found senses:
#   • a metallic tapping sound
#   • any of two families of small parasitic arachnids with barbed proboscis; feed on blood of warm-blooded animals
#
# ==============================
# Story: ('tick', 'Tom settled into his new cabin deep in the woods, excited for some peace and quiet. The old floorboards creaked whenever he walked over them. During the night, an odd noise kept echoing through the silent room.', 'He was up all night because of the tick.', '')
# Found senses:
#   • a metallic tapping sound
#   • any of two families of small parasitic arachnids with barbed proboscis; feed on blood of warm-blooded animals
#
# ==============================
# Story: ('palms', 'Jack and Emma arrived at the park early in the morning. They walked slowly, admiring the scenery. Emma paused and pointed out something interesting nearby.', 'She took a photo of the palms.', 'She wanted a photo of the monster insect before it flew away.')
# Found senses:
#   • any plant of the family Palmae having an unbranched trunk crowned by large pinnate or palmate leaves
#   • the inner surface of the hand from the wrist to the base of the fingers
#
# ==============================
# Story: ('palms', 'Jack and Emma arrived at the park early in the morning. They walked slowly, admiring the scenery. Emma paused and pointed out something interesting nearby.', 'She took a photo of the palms.', 'They were green and such a beautiful scenery.')
# Found senses:
#   • any plant of the family Palmae having an unbranched trunk crowned by large pinnate or palmate leaves
#   • the inner surface of the hand from the wrist to the base of the fingers
#
# ==============================
# Story: ('palms', 'Jack and Emma arrived at the park early in the morning. They walked slowly, admiring the scenery. Emma paused and pointed out something interesting nearby.', 'She took a photo of the palms.', '')
# Found senses:
#   • any plant of the family Palmae having an unbranched trunk crowned by large pinnate or palmate leaves
#   • the inner surface of the hand from the wrist to the base of the fingers
#
# ==============================
# Story: ('class', 'Lila received an invitation to an exclusive gathering. She knew it would be held at a grand estate. Curiosity led her to accept and see who would be there.', 'When attending the function at the stately home, she noticed the class of people there.', 'She was shocked to see the number of people there, but decided to walk over and have a talk with them.')
# Found senses:
#   • a body of students who are taught together
#   • elegance in dress or behavior
#
# ==============================
# Story: ('class', 'Lila received an invitation to an exclusive gathering. She knew it would be held at a grand estate. Curiosity led her to accept and see who would be there.', 'When attending the function at the stately home, she noticed the class of people there.', "She was glad she'd bought a fancy dress and hat before the day.")
# Found senses:
#   • a body of students who are taught together
#   • elegance in dress or behavior
#
# ==============================
# Story: ('class', 'Lila received an invitation to an exclusive gathering. She knew it would be held at a grand estate. Curiosity led her to accept and see who would be there.', 'When attending the function at the stately home, she noticed the class of people there.', '')
# Found senses:
#   • a body of students who are taught together
#   • elegance in dress or behavior
#
# ==============================
# Story: ('class', 'Students gathered in anticipation, eager to see what the day would bring. Mrs. Thompson always maintained a high standard in her lessons. Her unique approach and style set her apart from other teachers.', "The teacher's class was known for being distinguished.", 'As she required such a high standard from all of her pupils.')
# Found senses:
#   • a body of students who are taught together
#   • elegance in dress or behavior
#
# ==============================
# Story: ('class', 'Students gathered in anticipation, eager to see what the day would bring. Mrs. Thompson always maintained a high standard in her lessons. Her unique approach and style set her apart from other teachers.', "The teacher's class was known for being distinguished.", 'She dressed very well even in normal school lessons, and took great pride in how she looked.')
# Found senses:
#   • a body of students who are taught together
#   • elegance in dress or behavior
#
# ==============================
# Story: ('class', 'Students gathered in anticipation, eager to see what the day would bring. Mrs. Thompson always maintained a high standard in her lessons. Her unique approach and style set her apart from other teachers.', "The teacher's class was known for being distinguished.", '')
# Found senses:
#   • a body of students who are taught together
#   • elegance in dress or behavior
#
# ==============================
# Story: ('speakers', 'Dan sat at the back of the crowded hall. He watched as the panelists took their seats on stage. Everyone settled in, eagerly anticipating the start.', 'The speakers are too loud.', 'They were trying too hard to get their views across.')
# Found senses:
#   • someone who expresses in language; someone who talks (especially someone who delivers a public speech or someone especially garrulous)
#   • electro-acoustic transducer that converts electrical signals into sounds loud enough to be heard at a distance
#
# ==============================
# Story: ('speakers', 'Dan sat at the back of the crowded hall. He watched as the panelists took their seats on stage. Everyone settled in, eagerly anticipating the start.', 'The speakers are too loud.', 'They were so loud that the audience left the hall with severe headaches.')
# Found senses:
#   • someone who expresses in language; someone who talks (especially someone who delivers a public speech or someone especially garrulous)
#   • electro-acoustic transducer that converts electrical signals into sounds loud enough to be heard at a distance
#
# ==============================
# Story: ('speakers', 'Dan sat at the back of the crowded hall. He watched as the panelists took their seats on stage. Everyone settled in, eagerly anticipating the start.', 'The speakers are too loud.', '')
# Found senses:
#   • someone who expresses in language; someone who talks (especially someone who delivers a public speech or someone especially garrulous)
#   • electro-acoustic transducer that converts electrical signals into sounds loud enough to be heard at a distance
#
# ==============================
# Story: ('material', "Kate had a big project to finish by the end of the week. She was given a package that seemed important. Inside, she found some useful pieces but wasn't exactly sure about their purpose.", "Kate wasn't sure what to do with the material she had been given.", 'Surely if she writes well and uses it properly, the NYT will definitely pick it up.')
# Found senses:
#   • information (data or ideas or observations) that can be used or reworked into a finished form
#   • artifact made by weaving or felting or knitting or crocheting natural or synthetic fibers
#
# ==============================
# Story: ('material', "Kate had a big project to finish by the end of the week. She was given a package that seemed important. Inside, she found some useful pieces but wasn't exactly sure about their purpose.", "Kate wasn't sure what to do with the material she had been given.", 'She was sure that she could think of something to make soon; she just needed some ideas.')
# Found senses:
#   • information (data or ideas or observations) that can be used or reworked into a finished form
#   • artifact made by weaving or felting or knitting or crocheting natural or synthetic fibers
#
# ==============================
# Story: ('material', "Kate had a big project to finish by the end of the week. She was given a package that seemed important. Inside, she found some useful pieces but wasn't exactly sure about their purpose.", "Kate wasn't sure what to do with the material she had been given.", '')
# Found senses:
#   • information (data or ideas or observations) that can be used or reworked into a finished form
#   • artifact made by weaving or felting or knitting or crocheting natural or synthetic fibers
#
# ==============================
# Story: ('materials', 'James was known for his attention to detail in every project. He often spent hours researching and gathering everything he might need. His workshop was filled with various items and reference books, ready for any task.', "He carefully selected materials to enhance the project's quality.", 'James was recognized for his performance at the dinner night.')
# Found senses:
#   • information (data or ideas or observations) that can be used or reworked into a finished form
#   • artifact made by weaving or felting or knitting or crocheting natural or synthetic fibers
#
# ==============================
# Story: ('materials', 'James was known for his attention to detail in every project. He often spent hours researching and gathering everything he might need. His workshop was filled with various items and reference books, ready for any task.', "He carefully selected materials to enhance the project's quality.", 'Wrapping the fabric around the model he had made finished the project off nicely.')
# Found senses:
#   • information (data or ideas or observations) that can be used or reworked into a finished form
#   • artifact made by weaving or felting or knitting or crocheting natural or synthetic fibers
#
# ==============================
# Story: ('materials', 'James was known for his attention to detail in every project. He often spent hours researching and gathering everything he might need. His workshop was filled with various items and reference books, ready for any task.', "He carefully selected materials to enhance the project's quality.", '')
# Found senses:
#   • information (data or ideas or observations) that can be used or reworked into a finished form
#   • artifact made by weaving or felting or knitting or crocheting natural or synthetic fibers
#
# ==============================
# Story: ('material', 'The designers gathered around the table, staring at the blank sheets. They had been given a new project with a looming deadline. The client expected something innovative, yet specific guidelines were minimal.', 'It was hard to know what to do, as they had no material to work with.', 'They were stuck.')
# Found senses:
#   • information (data or ideas or observations) that can be used or reworked into a finished form
#   • artifact made by weaving or felting or knitting or crocheting natural or synthetic fibers
#
# ==============================
# Story: ('material', 'The designers gathered around the table, staring at the blank sheets. They had been given a new project with a looming deadline. The client expected something innovative, yet specific guidelines were minimal.', 'It was hard to know what to do, as they had no material to work with.', 'No leather, no cotton, no felt, or silk, or satin; there was nothing available at all.')
# Found senses:
#   • information (data or ideas or observations) that can be used or reworked into a finished form
#   • artifact made by weaving or felting or knitting or crocheting natural or synthetic fibers
#
# ==============================
# Story: ('material', 'The designers gathered around the table, staring at the blank sheets. They had been given a new project with a looming deadline. The client expected something innovative, yet specific guidelines were minimal.', 'It was hard to know what to do, as they had no material to work with.', '')
# Found senses:
#   • information (data or ideas or observations) that can be used or reworked into a finished form
#   • artifact made by weaving or felting or knitting or crocheting natural or synthetic fibers
#
# ==============================
# Story: ('material', 'Anna had been planning her project for weeks. She gathered all her supplies and set them on the table. Today was the day she would finally start.', 'She spread the new material across the table before beginning her project.', 'She found it helpful to be able to see all of her notes and Post-its at once.')
# Found senses:
#   • information (data or ideas or observations) that can be used or reworked into a finished form
#   • artifact made by weaving or felting or knitting or crocheting natural or synthetic fibers
#
# ==============================
# Story: ('material', 'Anna had been planning her project for weeks. She gathered all her supplies and set them on the table. Today was the day she would finally start.', 'She spread the new material across the table before beginning her project.', 'A fabric that is nice to touch.')
# Found senses:
#   • information (data or ideas or observations) that can be used or reworked into a finished form
#   • artifact made by weaving or felting or knitting or crocheting natural or synthetic fibers
#
# ==============================
# Story: ('material', 'Anna had been planning her project for weeks. She gathered all her supplies and set them on the table. Today was the day she would finally start.', 'She spread the new material across the table before beginning her project.', '')
# Found senses:
#   • information (data or ideas or observations) that can be used or reworked into a finished form
#   • artifact made by weaving or felting or knitting or crocheting natural or synthetic fibers
#
# ==============================
# Story: ('material', 'Alice had a big project due in her art class. It was supposed to showcase her creativity and skills. She gathered all her supplies and ideas in the living room.', 'She could not decide on what material to use to finish the school project.', 'She had a brainstorming session with all of her ideas to choose the best one.')
# Found senses:
#   • information (data or ideas or observations) that can be used or reworked into a finished form
#   • artifact made by weaving or felting or knitting or crocheting natural or synthetic fibers
#
# ==============================
# Story: ('material', 'Alice had a big project due in her art class. It was supposed to showcase her creativity and skills. She gathered all her supplies and ideas in the living room.', 'She could not decide on what material to use to finish the school project.', 'After much thought, she finally decided to use fabric, which she thinks will bring out the perfect texture for her project.')
# Found senses:
#   • information (data or ideas or observations) that can be used or reworked into a finished form
#   • artifact made by weaving or felting or knitting or crocheting natural or synthetic fibers
#
# ==============================
# ...
# Found senses:
#   • be inadequate or objectionable
#   • draw something in by or as if by a vacuum
#
# ==============================
# Story: ('mouse', "Tom sat at his desk, deep in thought. He glanced at the table where there were crumbs from the sandwich he'd eaten earlier. Something shifted slightly near the edge, catching his eye.", 'The mouse had a mind of its own.', "He was shocked, as he didn't know how it had gotten into his room.")
# Found senses:
#   • any of numerous small rodents typically resembling diminutive rats having pointed snouts and small ears on elongated bodies with slender usually hairless tails
#   • a hand-operated electronic device that controls the coordinates of a cursor on your computer screen as you move it around on a pad; on the bottom of the device is a ball that rolls on the surface of the pad
#
# ==============================
# Story: ('mouse', "Tom sat at his desk, deep in thought. He glanced at the table where there were crumbs from the sandwich he'd eaten earlier. Something shifted slightly near the edge, catching his eye.", 'The mouse had a mind of its own.', 'He reached out to move the little device so he could click the button.')
# Found senses:
#   • any of numerous small rodents typically resembling diminutive rats having pointed snouts and small ears on elongated bodies with slender usually hairless tails
#   • a hand-operated electronic device that controls the coordinates of a cursor on your computer screen as you move it around on a pad; on the bottom of the device is a ball that rolls on the surface of the pad
#
# ==============================
# Story: ('mouse', "Tom sat at his desk, deep in thought. He glanced at the table where there were crumbs from the sandwich he'd eaten earlier. Something shifted slightly near the edge, catching his eye.", 'The mouse had a mind of its own.', '')
# Found senses:
#   • any of numerous small rodents typically resembling diminutive rats having pointed snouts and small ears on elongated bodies with slender usually hairless tails
#   • a hand-operated electronic device that controls the coordinates of a cursor on your computer screen as you move it around on a pad; on the bottom of the device is a ball that rolls on the surface of the pad
#
# ==============================
# Story: ('steps', 'John was running late for the meeting that could change his career. He grabbed his briefcase, hoping he had everything he needed. The place was not far, but he knew he had to make quick decisions to get there on time.', 'He took steps to the place he needed to get to.', 'They were slippery after a night of heavy rain. He had to tread carefully.')
# Found senses:
#   • any maneuver made as part of progress toward a goal
#   • support consisting of a place to rest the foot while ascending or descending a stairway
#
# ==============================
# Story: ('steps', 'John was running late for the meeting that could change his career. He grabbed his briefcase, hoping he had everything he needed. The place was not far, but he knew he had to make quick decisions to get there on time.', 'He took steps to the place he needed to get to.', 'He decided to take a taxi in order to get there quickly.')
# Found senses:
#   • any maneuver made as part of progress toward a goal
#   • support consisting of a place to rest the foot while ascending or descending a stairway
#
# ==============================
# Story: ('steps', 'John was running late for the meeting that could change his career. He grabbed his briefcase, hoping he had everything he needed. The place was not far, but he knew he had to make quick decisions to get there on time.', 'He took steps to the place he needed to get to.', '')
# Found senses:
#   • any maneuver made as part of progress toward a goal
#   • support consisting of a place to rest the foot while ascending or descending a stairway
#
# ==============================
# Story: ('steps', 'John woke up early to prepare for his day. He had a clear plan in mind and knew exactly where he wanted to go. Standing at the front door, he took a moment to gather his thoughts.', 'There were several steps in his walk.', 'Sometimes, when he was in a hurry, he would skip down, but the surface was wet and icy, so he descended slowly.')
# Found senses:
#   • a flight of stairs or a flight of steps
#   • any maneuver made as part of progress toward a goal
#
# ==============================
# Story: ('steps', 'John woke up early to prepare for his day. He had a clear plan in mind and knew exactly where he wanted to go. Standing at the front door, he took a moment to gather his thoughts.', 'There were several steps in his walk.', 'He formulated a plan in his mind in order to reach his goal.')
# Found senses:
#   • a flight of stairs or a flight of steps
#   • any maneuver made as part of progress toward a goal
#
# ==============================
# Story: ('steps', 'John woke up early to prepare for his day. He had a clear plan in mind and knew exactly where he wanted to go. Standing at the front door, he took a moment to gather his thoughts.', 'There were several steps in his walk.', '')
# Found senses:
#   • a flight of stairs or a flight of steps
#   • any maneuver made as part of progress toward a goal
#
# ==============================
# Story: ('step', 'The woman was determined to help her son succeed. He struggled with both challenges and changes in his life. She knew it was crucial to guide him through the process carefully.', 'The woman asked her son to take each step one at a time.', 'The route up to the attic was a treacherous one.')
# Found senses:
#   • a flight of stairs or a flight of steps
#   • any maneuver made as part of progress toward a goal
#
# ==============================
# Story: ('step', 'The woman was determined to help her son succeed. He struggled with both challenges and changes in his life. She knew it was crucial to guide him through the process carefully.', 'The woman asked her son to take each step one at a time.', 'She advised him to focus on one small task at a time to reach his big dream.')
# Found senses:
#   • a flight of stairs or a flight of steps
#   • any maneuver made as part of progress toward a goal
#
# ==============================
# Story: ('step', 'The woman was determined to help her son succeed. He struggled with both challenges and changes in his life. She knew it was crucial to guide him through the process carefully.', 'The woman asked her son to take each step one at a time.', '')
# Found senses:
#   • a flight of stairs or a flight of steps
#   • any maneuver made as part of progress toward a goal
#
# ==============================
# Story: ('steps', 'Sarah had been waiting at the airport for hours. Her connecting flight was delayed due to bad weather. She was determined to reach her destination no matter what.', 'The woman had taken steps to get on the flight.', 'She ran up them quickly and wasted no time.')
# Found senses:
#   • a flight of stairs or a flight of steps
#   • any maneuver made as part of progress toward a goal
#
# ==============================
# Story: ('steps', 'Sarah had been waiting at the airport for hours. Her connecting flight was delayed due to bad weather. She was determined to reach her destination no matter what.', 'The woman had taken steps to get on the flight.', 'She spoke to the airline staff, rearranged her booking, and kept checking for any open seats that might get her there sooner.')
# Found senses:
#   • a flight of stairs or a flight of steps
#   • any maneuver made as part of progress toward a goal
#
# ==============================
# Story: ('steps', 'Sarah had been waiting at the airport for hours. Her connecting flight was delayed due to bad weather. She was determined to reach her destination no matter what.', 'The woman had taken steps to get on the flight.', '')
# Found senses:
#   • a flight of stairs or a flight of steps
#   • any maneuver made as part of progress toward a goal
#
# ==============================
# Story: ('steps', 'John had a big job interview in the city. He left his house early to ensure he had enough time. Along the way, he faced several obstacles but remained determined.', 'He took all the steps he needed to get to where he was going.', 'He was very disciplined.')
# Found senses:
#   • any maneuver made as part of progress toward a goal
#   • support consisting of a place to rest the foot while ascending or descending a stairway
#
# ==============================
# Story: ('steps', 'John had a big job interview in the city. He left his house early to ensure he had enough time. Along the way, he faced several obstacles but remained determined.', 'He took all the steps he needed to get to where he was going.', 'He had to be careful, as he had recently fallen and hurt his leg.')
# Found senses:
#   • any maneuver made as part of progress toward a goal
#   • support consisting of a place to rest the foot while ascending or descending a stairway
#
# ==============================
# Story: ('steps', 'John had a big job interview in the city. He left his house early to ensure he had enough time. Along the way, he faced several obstacles but remained determined.', 'He took all the steps he needed to get to where he was going.', '')
# Found senses:
#   • any maneuver made as part of progress toward a goal
#   • support consisting of a place to rest the foot while ascending or descending a stairway
#
# ==============================
# Story: ('steps', 'The old manor stood on the hill, looking as mysterious as ever. Two curious friends decided to explore its secrets one sunny afternoon. They entered cautiously, eager to uncover its hidden past.', 'They took several steps to get to where they wanted.', 'Their hard work and best efforts paid off; they found a room full of treasure!')
# Found senses:
#   • any maneuver made as part of progress toward a goal
#   • support consisting of a place to rest the foot while ascending or descending a stairway
#
# ==============================
# Story: ('steps', 'The old manor stood on the hill, looking as mysterious as ever. Two curious friends decided to explore its secrets one sunny afternoon. They entered cautiously, eager to uncover its hidden past.', 'They took several steps to get to where they wanted.', 'The journey was not easy, and it never will be.')
# Found senses:
#   • any maneuver made as part of progress toward a goal
#   • support consisting of a place to rest the foot while ascending or descending a stairway
#
# ==============================
# Story: ('steps', 'The old manor stood on the hill, looking as mysterious as ever. Two curious friends decided to explore its secrets one sunny afternoon. They entered cautiously, eager to uncover its hidden past.', 'They took several steps to get to where they wanted.', '')
# Found senses:
#   • any maneuver made as part of progress toward a goal
#   • support consisting of a place to rest the foot while ascending or descending a stairway
#
# ==============================
# Story: ('dough', 'John had always been meticulous with his hands. Every day, he laid everything out on the table just so. Today, he was determined to make something perfect.', 'He carefully looked at the dough.', 'And when he was done, it was nothing short of perfect!')
# Found senses:
#   • a flour mixture stiff enough to knead or roll
#   • informal terms for money
#
# ==============================
# Story: ('dough', 'John had always been meticulous with his hands. Every day, he laid everything out on the table just so. Today, he was determined to make something perfect.', 'He carefully looked at the dough.', 'He realized that he would have to get some more money from the cash point later in the day.')
# Found senses:
#   • a flour mixture stiff enough to knead or roll
#   • informal terms for money
#
# ==============================
# Story: ('dough', 'John had always been meticulous with his hands. Every day, he laid everything out on the table just so. Today, he was determined to make something perfect.', 'He carefully looked at the dough.', '')
# Found senses:
#   • a flour mixture stiff enough to knead or roll
#   • informal terms for money
#
# ==============================
# Story: ('dough', 'Emma and Jake had been saving up for months for their big plan. They spent the whole afternoon preparing everything they needed. The excitement in the air was tangible as they gathered their supplies.', "They were very devastated because they didn't have any more dough left.", 'They would have to make more with what flour they had left.')
# Found senses:
#   • a flour mixture stiff enough to knead or roll
#   • informal terms for money
#
# ==============================
# Story: ('dough', 'Emma and Jake had been saving up for months for their big plan. They spent the whole afternoon preparing everything they needed. The excitement in the air was tangible as they gathered their supplies.', "They were very devastated because they didn't have any more dough left.", 'As they reached their wallet, they noticed that they had to earn more to make their dream become a reality.')
# Found senses:
#   • a flour mixture stiff enough to knead or roll
#   • informal terms for money
#
# ==============================
# Story: ('dough', 'Emma and Jake had been saving up for months for their big plan. They spent the whole afternoon preparing everything they needed. The excitement in the air was tangible as they gathered their supplies.', "They were very devastated because they didn't have any more dough left.", '')
# Found senses:
#   • a flour mixture stiff enough to knead or roll
#   • informal terms for money
#
# ==============================
# Story: ('dough', 'The family gathered around the small table, looking hopeful. With the fridge nearly empty, they needed to come up with a plan. Mom looked at Dad with a knowing smile.', 'Having enough dough will satisfy the whole family.', 'She sent Dad out to the shops to secure some stiff flour mixture.')
# Found senses:
#   • a flour mixture stiff enough to knead or roll
#   • informal terms for money
#
# ==============================
# Story: ('dough', 'The family gathered around the small table, looking hopeful. With the fridge nearly empty, they needed to come up with a plan. Mom looked at Dad with a knowing smile.', 'Having enough dough will satisfy the whole family.', 'Then, we can buy whatever we want for dinner.')
# Found senses:
#   • a flour mixture stiff enough to knead or roll
#   • informal terms for money
#
# ==============================
# Story: ('dough', 'The family gathered around the small table, looking hopeful. With the fridge nearly empty, they needed to come up with a plan. Mom looked at Dad with a knowing smile.', 'Having enough dough will satisfy the whole family.', '')
# Found senses:
#   • a flour mixture stiff enough to knead or roll
#   • informal terms for money
#
# ==============================
# Story: ('dough', 'Tom stood at the counter, looking at the ingredients scattered before him. He had already spent most of his savings on this new venture. His friend, Jim, promised to help him figure things out.', 'Does he have more dough available?', 'Only time will tell if his loaves are good enough.')
# Found senses:
#   • a flour mixture stiff enough to knead or roll
#   • informal terms for money
#
# ==============================
# Story: ('dough', 'Tom stood at the counter, looking at the ingredients scattered before him. He had already spent most of his savings on this new venture. His friend, Jim, promised to help him figure things out.', 'Does he have more dough available?', 'He wondered if this new venture would result in his having to sell his car.')
# Found senses:
#   • a flour mixture stiff enough to knead or roll
#   • informal terms for money
#
# ==============================
# Story: ('dough', 'Tom stood at the counter, looking at the ingredients scattered before him. He had already spent most of his savings on this new venture. His friend, Jim, promised to help him figure things out.', 'Does he have more dough available?', '')
# Found senses:
#   • a flour mixture stiff enough to knead or roll
#   • informal terms for money
